# %% [markdown]
# <h1><b>Modul Pembelajaran Local Search & Optimization RKA 25</b></h1>

# %% [markdown]
# <h2><b>Environment Setup</b></h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random

# %% [markdown]
# <h2><b>1. Penjelasan Local Search dan Optimization</b></h2>
#
# **Apa itu Local Search?**
#
# Local Search adalah kelompok algoritma pencarian yang beroperasi pada **satu state** (atau sekumpulan state) saat ini,
# kemudian bergerak ke state tetangga (*neighbor*) tanpa perlu menyimpan seluruh pohon pencarian.
# Berbeda dengan Informed/Uninformed Search pada modul sebelumnya yang mencari **jalur** dari start ke goal,
# Local Search hanya fokus pada **state akhir yang optimal**.
#
# **Apa itu Optimization?**
#
# Optimization adalah proses menemukan solusi terbaik (global maximum atau global minimum) dari suatu ruang pencarian (*search space*).
# Dalam konteks AI, optimization sering digunakan untuk:
# - Tuning hyperparameter model
# - Penjadwalan & alokasi sumber daya
# - Pathfinding & routing
# - Constraint satisfaction
#
# **Konsep Penting:**
#
# | Konsep | Penjelasan |
# |---|---|
# | Objective / Fitness Function | Fungsi yang mengukur kualitas suatu solusi |
# | Local Optimum | Solusi terbaik di antara tetangga-tetangganya, tapi belum tentu terbaik secara keseluruhan |
# | Global Optimum | Solusi terbaik dari seluruh ruang pencarian |
# | State-Space Landscape | Representasi visual semua state beserta nilai objective function-nya |

# %% [markdown]
# <h2><b>2. Hill Climbing</b></h2>

# %% [markdown]
# <h3><b>2.1 Definisi</b></h3>
#
# Hill Climbing adalah algoritma pencarian heuristik dari keluarga Local Search. Algoritma ini bekerja dengan cara:
# - Secara iteratif berpindah dari state saat ini ke state tetangga yang **lebih baik** menurut fungsi evaluasi
# - Bersifat **greedy** — selalu memilih langkah yang memberikan perbaikan langsung
# - Merupakan varian dari *generate-and-test algorithm*
# - Tidak memerlukan penyimpanan seluruh pohon pencarian

# %% [markdown]
# <h3><b>2.2 Jenis-jenis Hill Climbing</b></h3>
#
# 1. **Simple Hill Climbing**: Evaluasi tetangga satu per satu, pilih **yang pertama** lebih baik dari state saat ini.
# 2. **Steepest-Ascent Hill Climbing**: Evaluasi **semua** tetangga, pilih yang memberikan peningkatan **terbesar**.
# 3. **Stochastic Hill Climbing**: Pilih tetangga secara **random**, terima jika lebih baik. Menambahkan unsur keacakan dalam pemilihan.

# %% [markdown]
# <h3><b>2.3 State-Space Diagram</b></h3>
#
# State-Space Diagram adalah representasi visual dari semua state yang mungkin dicapai algoritma:
# - **Sumbu-X**: State space (semua konfigurasi yang mungkin)
# - **Sumbu-Y**: Nilai objective function
#
# Konsep penting dalam diagram ini:
#
# | Konsep | Penjelasan |
# |---|---|
# | Local Maximum | State yang lebih baik dari tetangganya, tapi bukan yang terbaik secara keseluruhan |
# | Global Maximum | State terbaik di seluruh state-space — solusi optimal |
# | Plateau | Daerah datar di mana tetangga-tetangga memiliki nilai yang sama |
# | Ridge | Daerah tinggi dengan kemiringan yang bisa terlihat seperti puncak |
# | Shoulder | Plateau yang memiliki sisi menanjak — masih bisa naik jika ditelusuri |

# %% [markdown]
# <h3><b>2.4 Langkah-langkah</b></h3>
#
# 1. **State Awal**: Mulai dari solusi awal (bisa random)
# 2. **Generate Neighbor**: Buat solusi tetangga dengan melakukan perturbasi kecil pada state saat ini
# 3. **Evaluasi**: Hitung nilai objective function untuk setiap tetangga
# 4. **Pindah**: Jika ada tetangga yang lebih baik → pindah ke state tersebut
# 5. **Terminasi**: Ulangi hingga tidak ada tetangga yang lebih baik (konvergensi)

# %% [markdown]
# <h3><b>2.5 Kelebihan dan Kekurangan</b></h3>
#
# **Kelebihan:**
# - Sederhana dan mudah diimplementasikan
# - Efisien dalam menemukan local optima
# - Dapat diterapkan pada berbagai jenis masalah
#
# **Kekurangan:**
# - Dapat terjebak di **local optima** (bukan solusi terbaik global)
# - Kesulitan di daerah **plateau** (tidak tahu arah mana yang lebih baik)
# - Tidak menjamin solusi optimal

# %% [markdown]
# <h3><b>2.6 Implementasi</b></h3>

# %% [markdown]
# **Step 1:** Definisikan objective function dan fungsi pembangkit tetangga
#
# Kita gunakan fungsi sederhana: $$f(x) = -x^2 + 5 \cos(2 \pi x)$$ yang memiliki minimum di $x = 0$ dengan nilai $f(0) = 0$.

# %%
def objective(x):
    return -(x**2) + 5 * np.cos(2 * np.pi * x)

def generate_neighbors(x, step_size=0.1):
    return [np.array([x[0] + step_size]), np.array([x[0] - step_size])]

# %% [markdown]
# **Step 2:** Implementasi algoritma Hill Climbing

# %%
def hill_climbing(objective, initial, n_iterations=100, step_size=0.1):
    current = np.array([initial])
    
    current_eval = objective(current).item() 
    history = [(current[0], current_eval)]

    for i in range(n_iterations):
        neighbors = generate_neighbors(current, step_size)
        
        neighbor_evals = [objective(n).item() for n in neighbors] 
        best_idx = np.argmax(neighbor_evals) 

        if neighbor_evals[best_idx] > current_eval: 
            current = neighbors[best_idx]
            current_eval = neighbor_evals[best_idx]
            
            history.append((current[0], current_eval))
            print(f"Step {i+1}: x = {current[0]:.4f}, f(x) = {current_eval:.4f}")
        else:
            print("Tidak ada tetangga yang lebih baik. Algoritma konvergen.")
            break

    return current, current_eval, history

# %% [markdown]
# **Step 3:** Jalankan algoritma

# %%
initial_guess = 2.0
solution, value, history = hill_climbing(objective, initial_guess, n_iterations=100, step_size=0.1)
print(f"\nSolusi terbaik: x = {solution[0]:.4f}, f(x) = {value:.4f}")
# Out:
# Tidak ada tetangga yang lebih baik. Algoritma konvergen.
#
# Solusi terbaik: x = 2.0000, f(x) = 1.0000

# %% [markdown]
# **Step 4:** Visualisasi

# %%
x_range = np.linspace(-4, 4, 200)
# Mengganti rumus y_range agar persis dengan objective(x)
y_range = [-(x**2) + 5 * np.cos(2 * np.pi * x) for x in x_range]

hx = [h[0] for h in history]
hy = [h[1] for h in history]

plt.figure(figsize=(10, 5))
# Mengganti label agar sesuai dengan fungsi yang baru
plt.plot(x_range, y_range, 'b-', label='f(x) = -x^2 + 5 cos(2pi x)')
plt.plot(hx, hy, 'ro-', label='Jejak Hill Climbing', markersize=6)
plt.plot(hx[0], hy[0], 'gs', markersize=12, label='Start')
plt.plot(hx[-1], hy[-1], 'r*', markersize=15, label='Solusi')
plt.xlabel('x')
plt.ylabel('f(x)')
# Mengganti judul grafik
plt.title('Hill Climbing pada f(x) = -x^2 + 5 cos(2pi x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <h2><b>3. Simulated Annealing</b></h2>

# %% [markdown]
# <h3><b>3.1 Definisi</b></h3>
#
# Simulated Annealing (SA) adalah teknik optimization probabilistik yang terinspirasi dari proses **annealing** dalam metalurgi,
# yaitu proses pemanasan logam kemudian pendinginan secara perlahan untuk menghilangkan cacat dan mencapai struktur kristal yang stabil.
#
# Keunggulan utama SA dibanding Hill Climbing:
# - Mampu **keluar dari local optima** melalui probabilitas penerimaan solusi yang lebih buruk
# - Probabilitas ini berkurang seiring penurunan "suhu" (*temperature*)
# - Pada suhu tinggi → eksplorasi luas; pada suhu rendah → eksploitasi lokal

# %% [markdown]
# <h3><b>3.2 Langkah-langkah</b></h3>
#
# 1. **Inisialisasi**: Mulai dengan solusi awal $S_0$ dan suhu awal $T_0$
# 2. **Neighborhood Search**: Generate solusi baru $S'$ dengan perturbasi kecil pada $S$
# 3. **Evaluasi**: Hitung $\Delta E = f(S') - f(S)$
# 4. **Acceptance Rule**:
#    - Jika $S'$ lebih baik ($\Delta E < 0$ untuk minimization) → **terima**
#    - Jika $S'$ lebih buruk → terima dengan probabilitas $P = e^{-\Delta E / T}$
# 5. **Cooling Schedule**: Kurangi suhu $T$ setiap iterasi: $T_{baru} = \alpha \cdot T$ (exponential cooling)
# 6. **Terminasi**: Suhu sangat rendah atau iterasi habis

# %% [markdown]
# <h3><b>3.3 Cooling Schedule</b></h3>
#
# Cooling schedule sangat mempengaruhi performa SA:
# - Terlalu cepat → *premature convergence* (terjebak di local optimum)
# - Terlalu lambat → waktu komputasi sangat lama
#
# Contoh cooling schedule:
# - **Exponential**: $T_{baru} = \alpha \cdot T$, dengan $\alpha \in [0.8, 0.99]$
# - **Linear**: $T_{baru} = T - \Delta T$
# - **Logarithmic**: $T_{baru} = \frac{T_0}{\ln(1 + t)}$

# %% [markdown]
# <h3><b>3.4 Kelebihan dan Kekurangan</b></h3>
#
# **Kelebihan:**
# - Mampu keluar dari local minima/maxima
# - Implementasi sederhana
# - Mendekati global optimum dengan cooling schedule yang tepat
# - Fleksibel — bisa untuk masalah kontinu maupun diskrit
#
# **Kekurangan:**
# - Sensitif terhadap parameter (suhu awal, cooling rate)
# - Waktu komputasi bisa lama
# - Konvergensi lebih lambat dibanding metode deterministik

# %% [markdown]
# <h3><b>3.5 Perbandingan SA vs Hill Climbing</b></h3>
#
# | Aspek | Hill Climbing | Simulated Annealing |
# |---|---|---|
# | Escape local optima | ✗ Tidak bisa | ✓ Bisa (probabilistik) |
# | Penerimaan solusi buruk | Tidak pernah | Ya, dengan probabilitas $e^{-\Delta E / T}$ |
# | Kecepatan | Cepat | Lebih lambat |
# | Hasil | Local optimum | Mendekati global optimum |

# %% [markdown]
# <h3><b>3.6 Implementasi</b></h3>

# %% [markdown]
# **Step 1:** Definisikan objective function (sama dengan Hill Climbing untuk perbandingan)

# %%
def objective_sa(x):
    return -(x**2) + 5 * np.cos(2 * np.pi * x)

# %% [markdown]
# **Step 2:** Implementasi Simulated Annealing

# %%
def simulated_annealing(objective, initial, T=100, alpha=0.95, n_iterations=1000, step_size=0.5):
    current = initial
    current_eval = objective(current)
    best = current
    best_eval = current_eval
    history = [(current, current_eval, T)]

    for i in range(n_iterations):
        # Generate tetangga random
        neighbor = current + random.uniform(-step_size, step_size)
        neighbor_eval = objective(neighbor)

        # Hitung delta
        delta = neighbor_eval - current_eval

        # Acceptance rule untuk MAXIMIZATION
        if delta > 0: # UBAH DI SINI: Jika nilai baru lebih BESAR, terima
            current = neighbor
            current_eval = neighbor_eval
            if current_eval > best_eval: # UBAH DI SINI: Cari best_eval terbesar
                best = current
                best_eval = current_eval
        else:
            # Probabilitas menerima solusi yang lebih buruk (delta bernilai negatif)
            prob = math.exp(delta / T) # TETAP: delta sudah negatif, jadi delta/T aman
            if random.random() < prob:
                current = neighbor
                current_eval = neighbor_eval

        # Cooling schedule
        T = T * alpha
        history.append((current, current_eval, T))

        print(f"Step {i+1}: x = {current:.4f}, f(x) = {current_eval:.4f}")

        if T < 1e-10:
            break

    return best, best_eval, history

# %% [markdown]
# **Step 3:** Jalankan dan tampilkan hasil

# %%
best, best_eval, history_sa = simulated_annealing(objective_sa, initial=2.0)
print(f"Solusi terbaik: x = {best:.4f}, f(x) = {best_eval:.4f}")
# Out:
# Step 1: x = 1.8140, f(x) = -1.3327
# Step 2: x = 2.0938, f(x) = -0.2279
# Step 3: x = 1.9607, f(x) = 1.0038
# Step 4: x = 1.7716, f(x) = -2.4607
# Step 5: x = 1.3345, f(x) = -4.3129
# Step 6: x = 1.3118, f(x) = -3.6136
# Step 7: x = 1.4456, f(x) = -6.7999
# Step 8: x = 1.3230, f(x) = -3.9642
# Step 9: x = 1.7301, f(x) = -3.6162
# Step 10: x = 1.7301, f(x) = -3.6162
# Step 11: x = 2.1806, f(x) = -2.6436
# Step 12: x = 2.0100, f(x) = 0.9502
# Step 13: x = 2.4607, f(x) = -10.9033
# Step 14: x = 1.9896, f(x) = 1.0308
# Step 15: x = 1.9789, f(x) = 1.0401
# Step 16: x = 1.9789, f(x) = 1.0401
# Step 17: x = 1.8446, f(x) = -0.6037
# Step 18: x = 1.5415, f(x) = -7.2074
# Step 19: x = 1.3425, f(x) = -4.5460
# Step 20: x = 1.0396, f(x) = 3.7657
# Step 21: x = 0.5434, f(x) = -5.1105
# Step 22: x = 0.1252, f(x) = 3.5155
# Step 23: x = 0.3742, f(x) = -3.6584
# Step 24: x = 0.7264, f(x) = -1.2649
# Step 25: x = 0.8951, f(x) = 3.1521
# Step 26: x = 1.0907, f(x) = 3.0192
# Step 27: x = 1.2579, f(x) = -1.8309
# Step 28: x = 1.2579, f(x) = -1.8309
# Step 29: x = 0.7741, f(x) = 0.1563
# Step 30: x = 0.3513, f(x) = -3.0943
# Step 31: x = 0.3707, f(x) = -3.5756
# Step 32: x = 0.5531, f(x) = -5.0300
# Step 33: x = 0.5540, f(x) = -5.0219
# Step 34: x = 0.4690, f(x) = -5.1256
# Step 35: x = 0.3332, f(x) = -2.6072
# Step 36: x = 0.1033, f(x) = 3.9728
# Step 37: x = 0.1924, f(x) = 1.7342
# Step 38: x = -0.0823, f(x) = 4.3394
# Step 39: x = 0.0748, f(x) = 4.4522
# Step 40: x = 0.0748, f(x) = 4.4522
# Step 41: x = 0.0748, f(x) = 4.4522
# Step 42: x = -0.2686, f(x) = -0.6537
# Step 43: x = -0.4661, f(x) = -5.1044
# Step 44: x = -0.2223, f(x) = 0.8151
# Step 45: x = -0.3014, f(x) = -1.6771
# Step 46: x = -0.0741, f(x) = 4.4618
# Step 47: x = -0.0741, f(x) = 4.4618
# Step 48: x = -0.0742, f(x) = 4.4615
# Step 49: x = -0.0742, f(x) = 4.4615
# Step 50: x = -0.0742, f(x) = 4.4615
# Step 51: x = -0.0742, f(x) = 4.4615
# Step 52: x = 0.2608, f(x) = -0.4056
# Step 53: x = 0.0062, f(x) = 4.9962
# Step 54: x = 0.0062, f(x) = 4.9962
# Step 55: x = -0.2146, f(x) = 1.0568
# Step 56: x = -0.6899, f(x) = -2.3187
# Step 57: x = -0.6899, f(x) = -2.3187
# Step 58: x = -1.0053, f(x) = 3.9865
# Step 59: x = -1.1224, f(x) = 2.3323
# Step 60: x = -1.1224, f(x) = 2.3323
# Step 61: x = -1.1198, f(x) = 2.3964
# Step 62: x = -0.8863, f(x) = 2.9927
# Step 63: x = -0.8863, f(x) = 2.9927
# Step 64: x = -0.8863, f(x) = 2.9927
# Step 65: x = -0.8863, f(x) = 2.9927
# Step 66: x = -0.8863, f(x) = 2.9927
# Step 67: x = -0.8863, f(x) = 2.9927
# Step 68: x = -0.8543, f(x) = 2.3181
# Step 69: x = -1.1484, f(x) = 1.6594
# Step 70: x = -1.1484, f(x) = 1.6594
# Step 71: x = -1.1484, f(x) = 1.6594
# Step 72: x = -1.1484, f(x) = 1.6594
# Step 73: x = -0.9192, f(x) = 3.5239
# Step 74: x = -0.9605, f(x) = 3.9245
# Step 75: x = -0.9605, f(x) = 3.9245
# Step 76: x = -1.1090, f(x) = 2.6419
# Step 77: x = -0.7641, f(x) = -0.1411
# Step 78: x = -1.2255, f(x) = -0.7356
# Step 79: x = -1.2255, f(x) = -0.7356
# Step 80: x = -1.2255, f(x) = -0.7356
# Step 81: x = -0.9172, f(x) = 3.4974
# Step 82: x = -0.9172, f(x) = 3.4974
# Step 83: x = -0.9172, f(x) = 3.4974
# Step 84: x = -0.9172, f(x) = 3.4974
# Step 85: x = -0.8586, f(x) = 2.4149
# Step 86: x = -1.0382, f(x) = 3.7791
# Step 87: x = -1.0382, f(x) = 3.7791
# Step 88: x = -1.0484, f(x) = 3.6720
# Step 89: x = -1.0484, f(x) = 3.6720
# Step 90: x = -1.0484, f(x) = 3.6720
# Step 91: x = -1.0484, f(x) = 3.6720
# Step 92: x = -0.9947, f(x) = 4.0078
# Step 93: x = -0.9947, f(x) = 4.0078
# Step 94: x = -0.9947, f(x) = 4.0078
# Step 95: x = -0.9947, f(x) = 4.0078
# Step 96: x = -0.9947, f(x) = 4.0078
# Step 97: x = -0.9947, f(x) = 4.0078
# Step 98: x = -0.9947, f(x) = 4.0078
# Step 99: x = -0.9818, f(x) = 4.0034
# Step 100: x = -1.0217, f(x) = 3.9100
# Step 101: x = -1.0217, f(x) = 3.9100
# Step 102: x = -1.0217, f(x) = 3.9100
# Step 103: x = -1.0217, f(x) = 3.9100
# Step 104: x = -1.0217, f(x) = 3.9100
# Step 105: x = -1.0217, f(x) = 3.9100
# Step 106: x = -1.0217, f(x) = 3.9100
# Step 107: x = -1.0217, f(x) = 3.9100
# Step 108: x = -1.0217, f(x) = 3.9100
# Step 109: x = -1.0217, f(x) = 3.9100
# Step 110: x = -1.0217, f(x) = 3.9100
# Step 111: x = -0.9703, f(x) = 3.9719
# Step 112: x = -0.9703, f(x) = 3.9719
# Step 113: x = -0.9703, f(x) = 3.9719
# Step 114: x = -0.9703, f(x) = 3.9719
# Step 115: x = -0.9703, f(x) = 3.9719
# Step 116: x = -0.9703, f(x) = 3.9719
# Step 117: x = -0.9703, f(x) = 3.9719
# Step 118: x = -0.9703, f(x) = 3.9719
# Step 119: x = -1.0021, f(x) = 3.9953
# Step 120: x = -1.0021, f(x) = 3.9953
# Step 121: x = -1.0021, f(x) = 3.9953
# Step 122: x = -1.0021, f(x) = 3.9953
# Step 123: x = -1.0021, f(x) = 3.9953
# Step 124: x = -1.0021, f(x) = 3.9953
# Step 125: x = -1.0021, f(x) = 3.9953
# Step 126: x = -1.0021, f(x) = 3.9953
# Step 127: x = -1.0021, f(x) = 3.9953
# Step 128: x = -1.0021, f(x) = 3.9953
# Step 129: x = -1.0021, f(x) = 3.9953
# Step 130: x = -1.0021, f(x) = 3.9953
# Step 131: x = -1.0021, f(x) = 3.9953
# Step 132: x = -1.0021, f(x) = 3.9953
# Step 133: x = -1.0021, f(x) = 3.9953
# Step 134: x = -1.0021, f(x) = 3.9953
# Step 135: x = -1.0021, f(x) = 3.9953
# Step 136: x = -1.0021, f(x) = 3.9953
# Step 137: x = -1.0021, f(x) = 3.9953
# Step 138: x = -1.0021, f(x) = 3.9953
# Step 139: x = -1.0021, f(x) = 3.9953
# Step 140: x = -1.0021, f(x) = 3.9953
# Step 141: x = -1.0021, f(x) = 3.9953
# Step 142: x = -1.0021, f(x) = 3.9953
# Step 143: x = -1.0021, f(x) = 3.9953
# Step 144: x = -1.0021, f(x) = 3.9953
# Step 145: x = -1.0021, f(x) = 3.9953
# Step 146: x = -1.0021, f(x) = 3.9953
# Step 147: x = -1.0021, f(x) = 3.9953
# Step 148: x = -1.0021, f(x) = 3.9953
# Step 149: x = -1.0021, f(x) = 3.9953
# Step 150: x = -1.0021, f(x) = 3.9953
# Step 151: x = -1.0021, f(x) = 3.9953
# Step 152: x = -1.0021, f(x) = 3.9953
# Step 153: x = -1.0021, f(x) = 3.9953
# Step 154: x = -1.0021, f(x) = 3.9953
# Step 155: x = -1.0021, f(x) = 3.9953
# Step 156: x = -1.0021, f(x) = 3.9953
# Step 157: x = -1.0021, f(x) = 3.9953
# Step 158: x = -1.0021, f(x) = 3.9953
# Step 159: x = -1.0021, f(x) = 3.9953
# Step 160: x = -1.0021, f(x) = 3.9953
# Step 161: x = -1.0021, f(x) = 3.9953
# Step 162: x = -1.0021, f(x) = 3.9953
# Step 163: x = -1.0021, f(x) = 3.9953
# Step 164: x = -1.0021, f(x) = 3.9953
# Step 165: x = -1.0021, f(x) = 3.9953
# Step 166: x = -1.0021, f(x) = 3.9953
# Step 167: x = -1.0021, f(x) = 3.9953
# Step 168: x = -1.0021, f(x) = 3.9953
# Step 169: x = -1.0021, f(x) = 3.9953
# Step 170: x = -1.0021, f(x) = 3.9953
# Step 171: x = -1.0021, f(x) = 3.9953
# Step 172: x = -1.0021, f(x) = 3.9953
# Step 173: x = -1.0021, f(x) = 3.9953
# Step 174: x = -1.0021, f(x) = 3.9953
# Step 175: x = -1.0021, f(x) = 3.9953
# Step 176: x = -1.0021, f(x) = 3.9953
# Step 177: x = -1.0021, f(x) = 3.9953
# Step 178: x = -1.0021, f(x) = 3.9953
# Step 179: x = -1.0021, f(x) = 3.9953
# Step 180: x = -1.0021, f(x) = 3.9953
# Step 181: x = -1.0021, f(x) = 3.9953
# Step 182: x = -0.9826, f(x) = 4.0047
# Step 183: x = -0.9826, f(x) = 4.0047
# Step 184: x = -0.9826, f(x) = 4.0047
# Step 185: x = -0.9826, f(x) = 4.0047
# Step 186: x = -0.9826, f(x) = 4.0047
# Step 187: x = -0.9826, f(x) = 4.0047
# Step 188: x = -0.9826, f(x) = 4.0047
# Step 189: x = -0.9826, f(x) = 4.0047
# Step 190: x = -0.9826, f(x) = 4.0047
# Step 191: x = -0.9826, f(x) = 4.0047
# Step 192: x = -0.9826, f(x) = 4.0047
# Step 193: x = -0.9850, f(x) = 4.0076
# Step 194: x = -0.9850, f(x) = 4.0076
# Step 195: x = -0.9850, f(x) = 4.0076
# Step 196: x = -0.9850, f(x) = 4.0076
# Step 197: x = -0.9850, f(x) = 4.0076
# Step 198: x = -0.9850, f(x) = 4.0076
# Step 199: x = -0.9850, f(x) = 4.0076
# Step 200: x = -0.9850, f(x) = 4.0076
# Step 201: x = -0.9850, f(x) = 4.0076
# Step 202: x = -0.9850, f(x) = 4.0076
# Step 203: x = -0.9850, f(x) = 4.0076
# Step 204: x = -0.9850, f(x) = 4.0076
# Step 205: x = -0.9850, f(x) = 4.0076
# Step 206: x = -0.9850, f(x) = 4.0076
# Step 207: x = -0.9870, f(x) = 4.0092
# Step 208: x = -0.9870, f(x) = 4.0092
# Step 209: x = -0.9870, f(x) = 4.0092
# Step 210: x = -0.9870, f(x) = 4.0092
# Step 211: x = -0.9870, f(x) = 4.0092
# Step 212: x = -0.9870, f(x) = 4.0092
# Step 213: x = -0.9870, f(x) = 4.0092
# Step 214: x = -0.9870, f(x) = 4.0092
# Step 215: x = -0.9870, f(x) = 4.0092
# Step 216: x = -0.9870, f(x) = 4.0092
# Step 217: x = -0.9870, f(x) = 4.0092
# Step 218: x = -0.9870, f(x) = 4.0092
# Step 219: x = -0.9870, f(x) = 4.0092
# Step 220: x = -0.9870, f(x) = 4.0092
# Step 221: x = -0.9870, f(x) = 4.0092
# Step 222: x = -0.9870, f(x) = 4.0092
# Step 223: x = -0.9870, f(x) = 4.0092
# Step 224: x = -0.9870, f(x) = 4.0092
# Step 225: x = -0.9870, f(x) = 4.0092
# Step 226: x = -0.9870, f(x) = 4.0092
# Step 227: x = -0.9870, f(x) = 4.0092
# Step 228: x = -0.9870, f(x) = 4.0092
# Step 229: x = -0.9870, f(x) = 4.0092
# Step 230: x = -0.9870, f(x) = 4.0092
# Step 231: x = -0.9870, f(x) = 4.0092
# Step 232: x = -0.9870, f(x) = 4.0092
# Step 233: x = -0.9870, f(x) = 4.0092
# Step 234: x = -0.9870, f(x) = 4.0092
# Step 235: x = -0.9870, f(x) = 4.0092
# Step 236: x = -0.9870, f(x) = 4.0092
# Step 237: x = -0.9870, f(x) = 4.0092
# Step 238: x = -0.9870, f(x) = 4.0092
# Step 239: x = -0.9870, f(x) = 4.0092
# Step 240: x = -0.9870, f(x) = 4.0092
# Step 241: x = -0.9870, f(x) = 4.0092
# Step 242: x = -0.9870, f(x) = 4.0092
# Step 243: x = -0.9870, f(x) = 4.0092
# Step 244: x = -0.9870, f(x) = 4.0092
# Step 245: x = -0.9870, f(x) = 4.0092
# Step 246: x = -0.9870, f(x) = 4.0092
# Step 247: x = -0.9870, f(x) = 4.0092
# Step 248: x = -0.9870, f(x) = 4.0092
# Step 249: x = -0.9870, f(x) = 4.0092
# Step 250: x = -0.9870, f(x) = 4.0092
# Step 251: x = -0.9870, f(x) = 4.0092
# Step 252: x = -0.9870, f(x) = 4.0092
# Step 253: x = -0.9870, f(x) = 4.0092
# Step 254: x = -0.9870, f(x) = 4.0092
# Step 255: x = -0.9870, f(x) = 4.0092
# Step 256: x = -0.9870, f(x) = 4.0092
# Step 257: x = -0.9870, f(x) = 4.0092
# Step 258: x = -0.9870, f(x) = 4.0092
# Step 259: x = -0.9870, f(x) = 4.0092
# Step 260: x = -0.9870, f(x) = 4.0092
# Step 261: x = -0.9870, f(x) = 4.0092
# Step 262: x = -0.9870, f(x) = 4.0092
# Step 263: x = -0.9870, f(x) = 4.0092
# Step 264: x = -0.9870, f(x) = 4.0092
# Step 265: x = -0.9870, f(x) = 4.0092
# Step 266: x = -0.9870, f(x) = 4.0092
# Step 267: x = -0.9870, f(x) = 4.0092
# Step 268: x = -0.9870, f(x) = 4.0092
# Step 269: x = -0.9870, f(x) = 4.0092
# Step 270: x = -0.9870, f(x) = 4.0092
# Step 271: x = -0.9870, f(x) = 4.0092
# Step 272: x = -0.9870, f(x) = 4.0092
# Step 273: x = -0.9870, f(x) = 4.0092
# Step 274: x = -0.9870, f(x) = 4.0092
# Step 275: x = -0.9870, f(x) = 4.0092
# Step 276: x = -0.9870, f(x) = 4.0092
# Step 277: x = -0.9870, f(x) = 4.0092
# Step 278: x = -0.9870, f(x) = 4.0092
# Step 279: x = -0.9870, f(x) = 4.0092
# Step 280: x = -0.9870, f(x) = 4.0092
# Step 281: x = -0.9870, f(x) = 4.0092
# Step 282: x = -0.9870, f(x) = 4.0092
# Step 283: x = -0.9870, f(x) = 4.0092
# Step 284: x = -0.9870, f(x) = 4.0092
# Step 285: x = -0.9870, f(x) = 4.0092
# Step 286: x = -0.9870, f(x) = 4.0092
# Step 287: x = -0.9870, f(x) = 4.0092
# Step 288: x = -0.9870, f(x) = 4.0092
# Step 289: x = -0.9870, f(x) = 4.0092
# Step 290: x = -0.9870, f(x) = 4.0092
# Step 291: x = -0.9870, f(x) = 4.0092
# Step 292: x = -0.9870, f(x) = 4.0092
# Step 293: x = -0.9870, f(x) = 4.0092
# Step 294: x = -0.9870, f(x) = 4.0092
# Step 295: x = -0.9870, f(x) = 4.0092
# Step 296: x = -0.9870, f(x) = 4.0092
# Step 297: x = -0.9870, f(x) = 4.0092
# Step 298: x = -0.9870, f(x) = 4.0092
# Step 299: x = -0.9870, f(x) = 4.0092
# Step 300: x = -0.9870, f(x) = 4.0092
# Step 301: x = -0.9870, f(x) = 4.0092
# Step 302: x = -0.9870, f(x) = 4.0092
# Step 303: x = -0.9870, f(x) = 4.0092
# Step 304: x = -0.9870, f(x) = 4.0092
# Step 305: x = -0.9870, f(x) = 4.0092
# Step 306: x = -0.9870, f(x) = 4.0092
# Step 307: x = -0.9870, f(x) = 4.0092
# Step 308: x = -0.9870, f(x) = 4.0092
# Step 309: x = -0.9870, f(x) = 4.0092
# Step 310: x = -0.9870, f(x) = 4.0092
# Step 311: x = -0.9870, f(x) = 4.0092
# Step 312: x = -0.9870, f(x) = 4.0092
# Step 313: x = -0.9870, f(x) = 4.0092
# Step 314: x = -0.9870, f(x) = 4.0092
# Step 315: x = -0.9870, f(x) = 4.0092
# Step 316: x = -0.9870, f(x) = 4.0092
# Step 317: x = -0.9870, f(x) = 4.0092
# Step 318: x = -0.9870, f(x) = 4.0092
# Step 319: x = -0.9870, f(x) = 4.0092
# Step 320: x = -0.9870, f(x) = 4.0092
# Step 321: x = -0.9870, f(x) = 4.0092
# Step 322: x = -0.9870, f(x) = 4.0092
# Step 323: x = -0.9870, f(x) = 4.0092
# Step 324: x = -0.9870, f(x) = 4.0092
# Step 325: x = -0.9870, f(x) = 4.0092
# Step 326: x = -0.9870, f(x) = 4.0092
# Step 327: x = -0.9870, f(x) = 4.0092
# Step 328: x = -0.9870, f(x) = 4.0092
# Step 329: x = -0.9870, f(x) = 4.0092
# Step 330: x = -0.9870, f(x) = 4.0092
# Step 331: x = -0.9870, f(x) = 4.0092
# Step 332: x = -0.9870, f(x) = 4.0092
# Step 333: x = -0.9870, f(x) = 4.0092
# Step 334: x = -0.9870, f(x) = 4.0092
# Step 335: x = -0.9870, f(x) = 4.0092
# Step 336: x = -0.9870, f(x) = 4.0092
# Step 337: x = -0.9870, f(x) = 4.0092
# Step 338: x = -0.9870, f(x) = 4.0092
# Step 339: x = -0.9870, f(x) = 4.0092
# Step 340: x = -0.9891, f(x) = 4.0100
# Step 341: x = -0.9891, f(x) = 4.0100
# Step 342: x = -0.9891, f(x) = 4.0100
# Step 343: x = -0.9891, f(x) = 4.0100
# Step 344: x = -0.9891, f(x) = 4.0100
# Step 345: x = -0.9891, f(x) = 4.0100
# Step 346: x = -0.9891, f(x) = 4.0100
# Step 347: x = -0.9891, f(x) = 4.0100
# Step 348: x = -0.9891, f(x) = 4.0100
# Step 349: x = -0.9891, f(x) = 4.0100
# Step 350: x = -0.9891, f(x) = 4.0100
# Step 351: x = -0.9891, f(x) = 4.0100
# Step 352: x = -0.9891, f(x) = 4.0100
# Step 353: x = -0.9891, f(x) = 4.0100
# Step 354: x = -0.9891, f(x) = 4.0100
# Step 355: x = -0.9891, f(x) = 4.0100
# Step 356: x = -0.9891, f(x) = 4.0100
# Step 357: x = -0.9891, f(x) = 4.0100
# Step 358: x = -0.9891, f(x) = 4.0100
# Step 359: x = -0.9891, f(x) = 4.0100
# Step 360: x = -0.9891, f(x) = 4.0100
# Step 361: x = -0.9891, f(x) = 4.0100
# Step 362: x = -0.9891, f(x) = 4.0100
# Step 363: x = -0.9891, f(x) = 4.0100
# Step 364: x = -0.9891, f(x) = 4.0100
# Step 365: x = -0.9891, f(x) = 4.0100
# Step 366: x = -0.9891, f(x) = 4.0100
# Step 367: x = -0.9891, f(x) = 4.0100
# Step 368: x = -0.9891, f(x) = 4.0100
# Step 369: x = -0.9891, f(x) = 4.0100
# Step 370: x = -0.9891, f(x) = 4.0100
# Step 371: x = -0.9891, f(x) = 4.0100
# Step 372: x = -0.9891, f(x) = 4.0100
# Step 373: x = -0.9891, f(x) = 4.0100
# Step 374: x = -0.9891, f(x) = 4.0100
# Step 375: x = -0.9891, f(x) = 4.0100
# Step 376: x = -0.9891, f(x) = 4.0100
# Step 377: x = -0.9891, f(x) = 4.0100
# Step 378: x = -0.9891, f(x) = 4.0100
# Step 379: x = -0.9891, f(x) = 4.0100
# Step 380: x = -0.9891, f(x) = 4.0100
# Step 381: x = -0.9891, f(x) = 4.0100
# Step 382: x = -0.9891, f(x) = 4.0100
# Step 383: x = -0.9891, f(x) = 4.0100
# Step 384: x = -0.9891, f(x) = 4.0100
# Step 385: x = -0.9891, f(x) = 4.0100
# Step 386: x = -0.9891, f(x) = 4.0100
# Step 387: x = -0.9891, f(x) = 4.0100
# Step 388: x = -0.9891, f(x) = 4.0100
# Step 389: x = -0.9891, f(x) = 4.0100
# Step 390: x = -0.9891, f(x) = 4.0100
# Step 391: x = -0.9891, f(x) = 4.0100
# Step 392: x = -0.9891, f(x) = 4.0100
# Step 393: x = -0.9891, f(x) = 4.0100
# Step 394: x = -0.9891, f(x) = 4.0100
# Step 395: x = -0.9891, f(x) = 4.0100
# Step 396: x = -0.9891, f(x) = 4.0100
# Step 397: x = -0.9891, f(x) = 4.0100
# Step 398: x = -0.9891, f(x) = 4.0100
# Step 399: x = -0.9891, f(x) = 4.0100
# Step 400: x = -0.9891, f(x) = 4.0100
# Step 401: x = -0.9891, f(x) = 4.0100
# Step 402: x = -0.9891, f(x) = 4.0100
# Step 403: x = -0.9891, f(x) = 4.0100
# Step 404: x = -0.9891, f(x) = 4.0100
# Step 405: x = -0.9891, f(x) = 4.0100
# Step 406: x = -0.9891, f(x) = 4.0100
# Step 407: x = -0.9891, f(x) = 4.0100
# Step 408: x = -0.9891, f(x) = 4.0100
# Step 409: x = -0.9891, f(x) = 4.0100
# Step 410: x = -0.9891, f(x) = 4.0100
# Step 411: x = -0.9891, f(x) = 4.0100
# Step 412: x = -0.9891, f(x) = 4.0100
# Step 413: x = -0.9891, f(x) = 4.0100
# Step 414: x = -0.9891, f(x) = 4.0100
# Step 415: x = -0.9891, f(x) = 4.0100
# Step 416: x = -0.9891, f(x) = 4.0100
# Step 417: x = -0.9891, f(x) = 4.0100
# Step 418: x = -0.9891, f(x) = 4.0100
# Step 419: x = -0.9891, f(x) = 4.0100
# Step 420: x = -0.9891, f(x) = 4.0100
# Step 421: x = -0.9891, f(x) = 4.0100
# Step 422: x = -0.9891, f(x) = 4.0100
# Step 423: x = -0.9891, f(x) = 4.0100
# Step 424: x = -0.9891, f(x) = 4.0100
# Step 425: x = -0.9891, f(x) = 4.0100
# Step 426: x = -0.9891, f(x) = 4.0100
# Step 427: x = -0.9891, f(x) = 4.0100
# Step 428: x = -0.9891, f(x) = 4.0100
# Step 429: x = -0.9891, f(x) = 4.0100
# Step 430: x = -0.9891, f(x) = 4.0100
# Step 431: x = -0.9891, f(x) = 4.0100
# Step 432: x = -0.9891, f(x) = 4.0100
# Step 433: x = -0.9891, f(x) = 4.0100
# Step 434: x = -0.9891, f(x) = 4.0100
# Step 435: x = -0.9891, f(x) = 4.0100
# Step 436: x = -0.9891, f(x) = 4.0100
# Step 437: x = -0.9891, f(x) = 4.0100
# Step 438: x = -0.9891, f(x) = 4.0100
# Step 439: x = -0.9891, f(x) = 4.0100
# Step 440: x = -0.9891, f(x) = 4.0100
# Step 441: x = -0.9891, f(x) = 4.0100
# Step 442: x = -0.9891, f(x) = 4.0100
# Step 443: x = -0.9891, f(x) = 4.0100
# Step 444: x = -0.9891, f(x) = 4.0100
# Step 445: x = -0.9891, f(x) = 4.0100
# Step 446: x = -0.9891, f(x) = 4.0100
# Step 447: x = -0.9891, f(x) = 4.0100
# Step 448: x = -0.9891, f(x) = 4.0100
# Step 449: x = -0.9891, f(x) = 4.0100
# Step 450: x = -0.9891, f(x) = 4.0100
# Step 451: x = -0.9891, f(x) = 4.0100
# Step 452: x = -0.9891, f(x) = 4.0100
# Step 453: x = -0.9891, f(x) = 4.0100
# Step 454: x = -0.9891, f(x) = 4.0100
# Step 455: x = -0.9891, f(x) = 4.0100
# Step 456: x = -0.9891, f(x) = 4.0100
# Step 457: x = -0.9891, f(x) = 4.0100
# Step 458: x = -0.9891, f(x) = 4.0100
# Step 459: x = -0.9891, f(x) = 4.0100
# Step 460: x = -0.9891, f(x) = 4.0100
# Step 461: x = -0.9891, f(x) = 4.0100
# Step 462: x = -0.9891, f(x) = 4.0100
# Step 463: x = -0.9891, f(x) = 4.0100
# Step 464: x = -0.9891, f(x) = 4.0100
# Step 465: x = -0.9891, f(x) = 4.0100
# Step 466: x = -0.9891, f(x) = 4.0100
# Step 467: x = -0.9891, f(x) = 4.0100
# Step 468: x = -0.9891, f(x) = 4.0100
# Step 469: x = -0.9891, f(x) = 4.0100
# Step 470: x = -0.9891, f(x) = 4.0100
# Step 471: x = -0.9891, f(x) = 4.0100
# Step 472: x = -0.9891, f(x) = 4.0100
# Step 473: x = -0.9891, f(x) = 4.0100
# Step 474: x = -0.9891, f(x) = 4.0100
# Step 475: x = -0.9891, f(x) = 4.0100
# Step 476: x = -0.9891, f(x) = 4.0100
# Step 477: x = -0.9891, f(x) = 4.0100
# Step 478: x = -0.9891, f(x) = 4.0100
# Step 479: x = -0.9891, f(x) = 4.0100
# Step 480: x = -0.9891, f(x) = 4.0100
# Step 481: x = -0.9891, f(x) = 4.0100
# Step 482: x = -0.9891, f(x) = 4.0100
# Step 483: x = -0.9891, f(x) = 4.0100
# Step 484: x = -0.9891, f(x) = 4.0100
# Step 485: x = -0.9891, f(x) = 4.0100
# Step 486: x = -0.9891, f(x) = 4.0100
# Step 487: x = -0.9891, f(x) = 4.0100
# Step 488: x = -0.9891, f(x) = 4.0100
# Step 489: x = -0.9891, f(x) = 4.0100
# Step 490: x = -0.9891, f(x) = 4.0100
# Step 491: x = -0.9891, f(x) = 4.0100
# Step 492: x = -0.9891, f(x) = 4.0100
# Step 493: x = -0.9891, f(x) = 4.0100
# Step 494: x = -0.9891, f(x) = 4.0100
# Step 495: x = -0.9891, f(x) = 4.0100
# Step 496: x = -0.9891, f(x) = 4.0100
# Step 497: x = -0.9891, f(x) = 4.0100
# Step 498: x = -0.9891, f(x) = 4.0100
# Step 499: x = -0.9891, f(x) = 4.0100
# Step 500: x = -0.9891, f(x) = 4.0100
# Step 501: x = -0.9891, f(x) = 4.0100
# Step 502: x = -0.9891, f(x) = 4.0100
# Step 503: x = -0.9891, f(x) = 4.0100
# Step 504: x = -0.9891, f(x) = 4.0100
# Step 505: x = -0.9891, f(x) = 4.0100
# Step 506: x = -0.9891, f(x) = 4.0100
# Step 507: x = -0.9891, f(x) = 4.0100
# Step 508: x = -0.9891, f(x) = 4.0100
# Step 509: x = -0.9891, f(x) = 4.0100
# Step 510: x = -0.9891, f(x) = 4.0100
# Step 511: x = -0.9891, f(x) = 4.0100
# Step 512: x = -0.9891, f(x) = 4.0100
# Step 513: x = -0.9891, f(x) = 4.0100
# Step 514: x = -0.9891, f(x) = 4.0100
# Step 515: x = -0.9891, f(x) = 4.0100
# Step 516: x = -0.9891, f(x) = 4.0100
# Step 517: x = -0.9891, f(x) = 4.0100
# Step 518: x = -0.9891, f(x) = 4.0100
# Step 519: x = -0.9891, f(x) = 4.0100
# Step 520: x = -0.9891, f(x) = 4.0100
# Step 521: x = -0.9891, f(x) = 4.0100
# Step 522: x = -0.9891, f(x) = 4.0100
# Step 523: x = -0.9891, f(x) = 4.0100
# Step 524: x = -0.9891, f(x) = 4.0100
# Step 525: x = -0.9891, f(x) = 4.0100
# Step 526: x = -0.9891, f(x) = 4.0100
# Step 527: x = -0.9891, f(x) = 4.0100
# Step 528: x = -0.9891, f(x) = 4.0100
# Step 529: x = -0.9891, f(x) = 4.0100
# Step 530: x = -0.9891, f(x) = 4.0100
# Step 531: x = -0.9894, f(x) = 4.0100
# Step 532: x = -0.9894, f(x) = 4.0100
# Step 533: x = -0.9894, f(x) = 4.0100
# Step 534: x = -0.9894, f(x) = 4.0100
# Step 535: x = -0.9894, f(x) = 4.0100
# Step 536: x = -0.9894, f(x) = 4.0100
# Step 537: x = -0.9894, f(x) = 4.0100
# Step 538: x = -0.9894, f(x) = 4.0100
# Step 539: x = -0.9894, f(x) = 4.0100
# Solusi terbaik: x = 0.0062, f(x) = 4.9962

# %% [markdown]
# **Step 4:** Visualisasi perbandingan konvergensi SA

# %%
iters = range(len(history_sa))
vals = [h[1] for h in history_sa]

# Ekstraksi suhu dari history, dengan rumus fallback jika data tidak tersedia
# Pastikan suhu awal (100) dan laju (0.95) cocok dengan kodemu yang sebenarnya
temps = [h[2] if len(h) > 2 else 100 * (0.95 ** i) for i, h in enumerate(history_sa)]

fig, ax1 = plt.subplots(figsize=(10, 5))

# Konfigurasi Sumbu Y Kiri untuk f(x)
color_fx = 'tab:blue'
ax1.set_xlabel('Iterasi')
ax1.set_ylabel('f(x)', color=color_fx)
ax1.plot(iters, vals, color=color_fx, alpha=0.6, label='Nilai f(x) per iterasi')
ax1.axhline(y=best_eval, color='r', linestyle='--', label=f'Terbaik: f(x)={best_eval:.4f}')
ax1.tick_params(axis='y', labelcolor=color_fx)
ax1.grid(True)

# Konfigurasi Sumbu Y Kanan untuk Suhu
ax2 = ax1.twinx()  
color_temp = 'tab:red'
ax2.set_ylabel('Suhu (T)', color=color_temp)  
ax2.plot(iters, temps, color=color_temp, alpha=0.8, label='Penurunan Suhu')
ax2.tick_params(axis='y', labelcolor=color_temp)

fig.tight_layout()  
plt.title('Konvergensi Simulated Annealing dan Perubahan Suhu')

# Menggabungkan legenda dari kedua sumbu agar rapi
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='lower right')

plt.show()

# %% [markdown]
# <h2><b>4. Genetic Algorithm</b></h2>

# %% [markdown]
# <h3><b>4.1 Definisi</b></h3>
#
# Genetic Algorithm (GA) adalah teknik optimization berbasis **populasi** yang terinspirasi dari prinsip **seleksi alam** dan **genetika**.
# Berbeda dengan Hill Climbing dan Simulated Annealing yang bekerja pada satu solusi, GA mengevolusi **populasi** solusi secara bersamaan.
#
# Karakteristik utama:
# - Bekerja pada banyak solusi sekaligus (population-based)
# - Menggunakan operator biologis: **selection**, **crossover**, **mutation**
# - Efektif untuk masalah non-linear, non-convex, dan multimodal
# - Tidak memerlukan informasi gradient

# %% [markdown]
# <h3><b>4.2 Konsep Utama</b></h3>
#
# | Konsep | Penjelasan |
# |---|---|
# | **Population** | Kumpulan candidate solutions pada satu generasi |
# | **Chromosome** | Satu candidate solution lengkap |
# | **Gene** | Unit terkecil dalam chromosome, merepresentasikan satu variabel |
# | **Fitness Function** | Fungsi yang mengevaluasi kualitas chromosome |
#
# **Metode Encoding:**
# - **Binary Encoding**: Menggunakan string biner (0 dan 1)
# - **Real-Valued Encoding**: Gene berupa bilangan real — cocok untuk optimization kontinu
# - **Permutation Encoding**: Chromosome merepresentasikan urutan — cocok untuk TSP, scheduling
#
# **Kriteria Terminasi:**
# - Jumlah generasi maksimum tercapai
# - Fitness threshold tercapai
# - Tidak ada perbaikan selama beberapa generasi
# - Batas waktu komputasi

# %% [markdown]
# <h3><b>4.3 Genetic Operator</b></h3>
#
# **a. Selection** — Memilih chromosome untuk menjadi parent:
# - **Roulette Wheel Selection**: Probabilitas seleksi proporsional terhadap fitness
# - **Tournament Selection**: Pilih acak beberapa individu, ambil yang terbaik
# - **Stochastic Universal Sampling (SUS)**: Versi perbaikan roulette wheel dengan multiple pointer
#
# **b. Crossover** — Menggabungkan genetic material dari dua parent:
# - **One-Point Crossover**: Satu titik potong random
# - **Multi-Point Crossover**: Dua titik potong random
# - **Davis Order Crossover (OX1)**: Untuk permutation encoding
# - **Uniform Crossover**: Tiap gene dipilih random dari salah satu parent
#
# **c. Mutation** — Perubahan random pada gene:
# - **Bit Flip**: Membalik bit (untuk binary encoding)
# - **Swap**: Menukar posisi dua gene
# - **Scramble**: Mengacak segmen dalam chromosome
# - **Inversion**: Membalik urutan segmen

# %% [markdown]
# <h3><b>4.4 Langkah-langkah</b></h3>
#
# 1. **Inisialisasi Populasi**: Generate populasi awal secara random
# 2. **Evaluasi Fitness**: Hitung fitness setiap chromosome
# 3. **Seleksi Parent**: Pilih parent berdasarkan fitness
# 4. **Crossover**: Gabungkan parent untuk menghasilkan offspring
# 5. **Mutasi**: Terapkan perubahan random pada offspring
# 6. **Pembentukan Generasi Baru**: Ganti populasi lama dengan offspring baru
# 7. **Cek Terminasi**: Periksa apakah kriteria berhenti terpenuhi
# 8. **Output**: Kembalikan chromosome terbaik

# %% [markdown]
# <h3><b>4.5 Kelebihan dan Kekurangan</b></h3>
#
# **Kelebihan:**
# - Efektif untuk masalah non-linear dan multimodal
# - Tidak memerlukan gradient — bisa untuk fungsi yang tidak differentiable
# - Population-based → eksplorasi ruang pencarian lebih luas
# - Fleksibel dalam representasi masalah
#
# **Kekurangan:**
# - Komputasi lebih mahal (banyak evaluasi fitness per generasi)
# - Banyak parameter yang harus di-tuning (population size, mutation rate, crossover rate)
# - Tidak menjamin menemukan global optimum

# %% [markdown]
# <h3><b>4.6 Implementasi</b></h3>

# %% [markdown]
# **Step 1:** Definisikan fitness function
#
# Kita gunakan fungsi multimodal $f(x) = x \cdot \sin(10\pi x) + 1$ untuk mendemonstrasikan kemampuan GA menghindari local optima.

# %%
def fitness_function(x):
    return x * np.sin(10 * np.pi * x) + 1

# %% [markdown]
# **Step 2:** Definisikan parameter dan inisialisasi populasi

# %%
POP_SIZE = 40
GENERATIONS = 1000
X_MIN, X_MAX = -1.0, 2.0
CROSSOVER_PROB = 0.9
MUTATION_PROB = 0.2
MUTATION_STD = 0.1

np.random.seed(42)
population = np.random.uniform(X_MIN, X_MAX, POP_SIZE)

# %% [markdown]
# **Step 3:** Implementasi genetix operator

# %%
def tournament_selection(pop, fitness, k=3):
    selected = []
    for _ in range(len(pop)):
        idx = np.random.choice(len(pop), k, replace=False)
        selected.append(pop[idx[np.argmax(fitness[idx])]])
    return np.array(selected)

def arithmetic_crossover(p1, p2):
    alpha = np.random.rand()
    return alpha * p1 + (1 - alpha) * p2, alpha * p2 + (1 - alpha) * p1

def mutate(x):
    if np.random.rand() < MUTATION_PROB:
        x += np.random.normal(0, MUTATION_STD)
    return np.clip(x, X_MIN, X_MAX)

# %% [markdown]
# **Step 4:** Loop evolusi

# %%
best_history = []
mean_history = []

for gen in range(GENERATIONS):
    fitness = fitness_function(population)
    best_history.append(np.max(fitness))
    mean_history.append(np.mean(fitness))

    # Mencari indeks individu terbaik di generasi ini untuk dicetak
    best_idx_gen = np.argmax(fitness)
    print(f"Step {gen+1}: x terbaik = {population[best_idx_gen]:.4f}, f(x) = {fitness[best_idx_gen]:.4f}")

    parents = tournament_selection(population, fitness)
    offspring = []
    np.random.shuffle(parents)

    for i in range(0, POP_SIZE, 2):
        if np.random.rand() < CROSSOVER_PROB:
            c1, c2 = arithmetic_crossover(parents[i], parents[i + 1])
        else:
            c1, c2 = parents[i], parents[i + 1]
        offspring.extend([mutate(c1), mutate(c2)])

    population = np.array(offspring)

# Hasil akhir
final_fitness = fitness_function(population)
best_idx = np.argmax(final_fitness)
print(f"Solusi terbaik: x = {population[best_idx]:.4f}, f(x) = {final_fitness[best_idx]:.4f}")
# Out:
# Step 1: x terbaik = 1.8521, f(x) = 2.8479
# Step 2: x terbaik = 1.4510, f(x) = 2.4503
# Step 3: x terbaik = 1.2496, f(x) = 2.2495
# Step 4: x terbaik = 1.2315, f(x) = 2.0297
# Step 5: x terbaik = 1.2631, f(x) = 2.1578
# Step 6: x terbaik = 1.2484, f(x) = 2.2468
# Step 7: x terbaik = 1.2519, f(x) = 2.2496
# Step 8: x terbaik = 1.2543, f(x) = 2.2429
# Step 9: x terbaik = 1.2537, f(x) = 2.2452
# Step 10: x terbaik = 1.2537, f(x) = 2.2451
# Step 11: x terbaik = 1.2537, f(x) = 2.2451
# Step 12: x terbaik = 1.2511, f(x) = 2.2504
# Step 13: x terbaik = 1.2517, f(x) = 2.2499
# Step 14: x terbaik = 1.2508, f(x) = 2.2504
# Step 15: x terbaik = 1.2508, f(x) = 2.2504
# Step 16: x terbaik = 1.2508, f(x) = 2.2504
# Step 17: x terbaik = 1.2508, f(x) = 2.2504
# Step 18: x terbaik = 1.2508, f(x) = 2.2504
# Step 19: x terbaik = 1.2508, f(x) = 2.2504
# Step 20: x terbaik = 1.4624, f(x) = 2.3537
# Step 21: x terbaik = 1.4551, f(x) = 2.4365
# Step 22: x terbaik = 1.2508, f(x) = 2.2504
# Step 23: x terbaik = 1.2508, f(x) = 2.2504
# Step 24: x terbaik = 1.2508, f(x) = 2.2504
# Step 25: x terbaik = 1.2508, f(x) = 2.2504
# Step 26: x terbaik = 1.2508, f(x) = 2.2504
# Step 27: x terbaik = 1.2508, f(x) = 2.2504
# Step 28: x terbaik = 1.2508, f(x) = 2.2504
# Step 29: x terbaik = 1.2508, f(x) = 2.2504
# Step 30: x terbaik = 1.4392, f(x) = 2.3579
# Step 31: x terbaik = 1.2508, f(x) = 2.2504
# Step 32: x terbaik = 1.2508, f(x) = 2.2504
# Step 33: x terbaik = 1.2508, f(x) = 2.2504
# Step 34: x terbaik = 1.4516, f(x) = 2.4498
# Step 35: x terbaik = 1.4504, f(x) = 2.4503
# Step 36: x terbaik = 1.4508, f(x) = 2.4503
# Step 37: x terbaik = 1.4508, f(x) = 2.4503
# Step 38: x terbaik = 1.6535, f(x) = 2.6433
# Step 39: x terbaik = 1.6535, f(x) = 2.6433
# Step 40: x terbaik = 1.6535, f(x) = 2.6433
# Step 41: x terbaik = 1.6509, f(x) = 2.6502
# Step 42: x terbaik = 1.6497, f(x) = 2.6497
# Step 43: x terbaik = 1.6467, f(x) = 2.6381
# Step 44: x terbaik = 1.6512, f(x) = 2.6501
# Step 45: x terbaik = 1.8476, f(x) = 2.8422
# Step 46: x terbaik = 1.8476, f(x) = 2.8422
# Step 47: x terbaik = 1.6525, f(x) = 2.6475
# Step 48: x terbaik = 1.6499, f(x) = 2.6498
# Step 49: x terbaik = 1.6505, f(x) = 2.6503
# Step 50: x terbaik = 1.6506, f(x) = 2.6503
# Step 51: x terbaik = 1.6506, f(x) = 2.6503
# Step 52: x terbaik = 1.6506, f(x) = 2.6503
# Step 53: x terbaik = 1.6506, f(x) = 2.6503
# Step 54: x terbaik = 1.6506, f(x) = 2.6503
# Step 55: x terbaik = 1.6506, f(x) = 2.6503
# Step 56: x terbaik = 1.8460, f(x) = 2.8312
# Step 57: x terbaik = 1.6506, f(x) = 2.6503
# Step 58: x terbaik = 1.6506, f(x) = 2.6503
# Step 59: x terbaik = 1.6506, f(x) = 2.6503
# Step 60: x terbaik = 1.6506, f(x) = 2.6503
# Step 61: x terbaik = 1.6506, f(x) = 2.6503
# Step 62: x terbaik = 1.6506, f(x) = 2.6503
# Step 63: x terbaik = 1.8374, f(x) = 2.6946
# Step 64: x terbaik = 1.6506, f(x) = 2.6503
# Step 65: x terbaik = 1.6506, f(x) = 2.6503
# Step 66: x terbaik = 1.8609, f(x) = 2.7535
# Step 67: x terbaik = 1.8609, f(x) = 2.7535
# Step 68: x terbaik = 1.8609, f(x) = 2.7535
# Step 69: x terbaik = 1.8522, f(x) = 2.8479
# Step 70: x terbaik = 1.8495, f(x) = 2.8493
# Step 71: x terbaik = 1.8530, f(x) = 2.8447
# Step 72: x terbaik = 1.8495, f(x) = 2.8493
# Step 73: x terbaik = 1.8499, f(x) = 2.8499
# Step 74: x terbaik = 1.8503, f(x) = 2.8502
# Step 75: x terbaik = 1.8505, f(x) = 2.8503
# Step 76: x terbaik = 1.8506, f(x) = 2.8503
# Step 77: x terbaik = 1.8506, f(x) = 2.8503
# Step 78: x terbaik = 1.8505, f(x) = 2.8503
# Step 79: x terbaik = 1.8505, f(x) = 2.8503
# Step 80: x terbaik = 1.8505, f(x) = 2.8503
# Step 81: x terbaik = 1.8505, f(x) = 2.8503
# Step 82: x terbaik = 1.8505, f(x) = 2.8503
# Step 83: x terbaik = 1.8505, f(x) = 2.8503
# Step 84: x terbaik = 1.8505, f(x) = 2.8503
# Step 85: x terbaik = 1.8505, f(x) = 2.8503
# Step 86: x terbaik = 1.8505, f(x) = 2.8503
# Step 87: x terbaik = 1.8505, f(x) = 2.8503
# Step 88: x terbaik = 1.8505, f(x) = 2.8503
# Step 89: x terbaik = 1.8505, f(x) = 2.8503
# Step 90: x terbaik = 1.8505, f(x) = 2.8503
# Step 91: x terbaik = 1.8505, f(x) = 2.8503
# Step 92: x terbaik = 1.8505, f(x) = 2.8503
# Step 93: x terbaik = 1.8505, f(x) = 2.8503
# Step 94: x terbaik = 1.8505, f(x) = 2.8503
# Step 95: x terbaik = 1.8505, f(x) = 2.8503
# Step 96: x terbaik = 1.8505, f(x) = 2.8503
# Step 97: x terbaik = 1.8505, f(x) = 2.8503
# Step 98: x terbaik = 1.8505, f(x) = 2.8503
# Step 99: x terbaik = 1.8505, f(x) = 2.8503
# Step 100: x terbaik = 1.8505, f(x) = 2.8503
# Step 101: x terbaik = 1.8505, f(x) = 2.8503
# Step 102: x terbaik = 1.8505, f(x) = 2.8503
# Step 103: x terbaik = 1.8505, f(x) = 2.8503
# Step 104: x terbaik = 1.8505, f(x) = 2.8503
# Step 105: x terbaik = 1.8505, f(x) = 2.8503
# Step 106: x terbaik = 1.8505, f(x) = 2.8503
# Step 107: x terbaik = 1.8505, f(x) = 2.8503
# Step 108: x terbaik = 1.8505, f(x) = 2.8503
# Step 109: x terbaik = 1.8505, f(x) = 2.8503
# Step 110: x terbaik = 1.8505, f(x) = 2.8503
# Step 111: x terbaik = 1.8505, f(x) = 2.8503
# Step 112: x terbaik = 1.8505, f(x) = 2.8503
# Step 113: x terbaik = 1.8505, f(x) = 2.8503
# Step 114: x terbaik = 1.8505, f(x) = 2.8503
# Step 115: x terbaik = 1.8505, f(x) = 2.8503
# Step 116: x terbaik = 1.8505, f(x) = 2.8503
# Step 117: x terbaik = 1.8505, f(x) = 2.8503
# Step 118: x terbaik = 1.8505, f(x) = 2.8503
# Step 119: x terbaik = 1.8505, f(x) = 2.8503
# Step 120: x terbaik = 1.8505, f(x) = 2.8503
# Step 121: x terbaik = 1.8505, f(x) = 2.8503
# Step 122: x terbaik = 1.8505, f(x) = 2.8503
# Step 123: x terbaik = 1.8505, f(x) = 2.8503
# Step 124: x terbaik = 1.8505, f(x) = 2.8503
# Step 125: x terbaik = 1.8505, f(x) = 2.8503
# Step 126: x terbaik = 1.8505, f(x) = 2.8503
# Step 127: x terbaik = 1.8505, f(x) = 2.8503
# Step 128: x terbaik = 1.8505, f(x) = 2.8503
# Step 129: x terbaik = 1.8505, f(x) = 2.8503
# Step 130: x terbaik = 1.8505, f(x) = 2.8503
# Step 131: x terbaik = 1.8505, f(x) = 2.8503
# Step 132: x terbaik = 1.8505, f(x) = 2.8503
# Step 133: x terbaik = 1.8505, f(x) = 2.8503
# Step 134: x terbaik = 1.8505, f(x) = 2.8503
# Step 135: x terbaik = 1.8505, f(x) = 2.8503
# Step 136: x terbaik = 1.8505, f(x) = 2.8503
# Step 137: x terbaik = 1.8505, f(x) = 2.8503
# Step 138: x terbaik = 1.8505, f(x) = 2.8503
# Step 139: x terbaik = 1.8505, f(x) = 2.8503
# Step 140: x terbaik = 1.8505, f(x) = 2.8503
# Step 141: x terbaik = 1.8505, f(x) = 2.8503
# Step 142: x terbaik = 1.8505, f(x) = 2.8503
# Step 143: x terbaik = 1.8505, f(x) = 2.8503
# Step 144: x terbaik = 1.8505, f(x) = 2.8503
# Step 145: x terbaik = 1.8505, f(x) = 2.8503
# Step 146: x terbaik = 1.8505, f(x) = 2.8503
# Step 147: x terbaik = 1.8505, f(x) = 2.8503
# Step 148: x terbaik = 1.8505, f(x) = 2.8503
# Step 149: x terbaik = 1.8505, f(x) = 2.8503
# Step 150: x terbaik = 1.8505, f(x) = 2.8503
# Step 151: x terbaik = 1.8505, f(x) = 2.8503
# Step 152: x terbaik = 1.8505, f(x) = 2.8503
# Step 153: x terbaik = 1.8505, f(x) = 2.8503
# Step 154: x terbaik = 1.8505, f(x) = 2.8503
# Step 155: x terbaik = 1.8505, f(x) = 2.8503
# Step 156: x terbaik = 1.8505, f(x) = 2.8503
# Step 157: x terbaik = 1.8505, f(x) = 2.8503
# Step 158: x terbaik = 1.8505, f(x) = 2.8503
# Step 159: x terbaik = 1.8505, f(x) = 2.8503
# Step 160: x terbaik = 1.8505, f(x) = 2.8503
# Step 161: x terbaik = 1.8505, f(x) = 2.8503
# Step 162: x terbaik = 1.8505, f(x) = 2.8503
# Step 163: x terbaik = 1.8505, f(x) = 2.8503
# Step 164: x terbaik = 1.8505, f(x) = 2.8503
# Step 165: x terbaik = 1.8505, f(x) = 2.8503
# Step 166: x terbaik = 1.8505, f(x) = 2.8503
# Step 167: x terbaik = 1.8505, f(x) = 2.8503
# Step 168: x terbaik = 1.8505, f(x) = 2.8503
# Step 169: x terbaik = 1.8505, f(x) = 2.8503
# Step 170: x terbaik = 1.8505, f(x) = 2.8503
# Step 171: x terbaik = 1.8505, f(x) = 2.8503
# Step 172: x terbaik = 1.8505, f(x) = 2.8503
# Step 173: x terbaik = 1.8505, f(x) = 2.8503
# Step 174: x terbaik = 1.8505, f(x) = 2.8503
# Step 175: x terbaik = 1.8505, f(x) = 2.8503
# Step 176: x terbaik = 1.8505, f(x) = 2.8503
# Step 177: x terbaik = 1.8505, f(x) = 2.8503
# Step 178: x terbaik = 1.8505, f(x) = 2.8503
# Step 179: x terbaik = 1.8505, f(x) = 2.8503
# Step 180: x terbaik = 1.8505, f(x) = 2.8503
# Step 181: x terbaik = 1.8505, f(x) = 2.8503
# Step 182: x terbaik = 1.8505, f(x) = 2.8503
# Step 183: x terbaik = 1.8505, f(x) = 2.8503
# Step 184: x terbaik = 1.8505, f(x) = 2.8503
# Step 185: x terbaik = 1.8505, f(x) = 2.8503
# Step 186: x terbaik = 1.8505, f(x) = 2.8503
# Step 187: x terbaik = 1.8505, f(x) = 2.8503
# Step 188: x terbaik = 1.8505, f(x) = 2.8503
# Step 189: x terbaik = 1.8505, f(x) = 2.8503
# Step 190: x terbaik = 1.8505, f(x) = 2.8503
# Step 191: x terbaik = 1.8505, f(x) = 2.8503
# Step 192: x terbaik = 1.8505, f(x) = 2.8503
# Step 193: x terbaik = 1.8505, f(x) = 2.8503
# Step 194: x terbaik = 1.8505, f(x) = 2.8503
# Step 195: x terbaik = 1.8505, f(x) = 2.8503
# Step 196: x terbaik = 1.8505, f(x) = 2.8503
# Step 197: x terbaik = 1.8505, f(x) = 2.8503
# Step 198: x terbaik = 1.8505, f(x) = 2.8503
# Step 199: x terbaik = 1.8505, f(x) = 2.8503
# Step 200: x terbaik = 1.8505, f(x) = 2.8503
# Step 201: x terbaik = 1.8505, f(x) = 2.8503
# Step 202: x terbaik = 1.8505, f(x) = 2.8503
# Step 203: x terbaik = 1.8505, f(x) = 2.8503
# Step 204: x terbaik = 1.8505, f(x) = 2.8503
# Step 205: x terbaik = 1.8505, f(x) = 2.8503
# Step 206: x terbaik = 1.8505, f(x) = 2.8503
# Step 207: x terbaik = 1.8505, f(x) = 2.8503
# Step 208: x terbaik = 1.8505, f(x) = 2.8503
# Step 209: x terbaik = 1.8505, f(x) = 2.8503
# Step 210: x terbaik = 1.8505, f(x) = 2.8503
# Step 211: x terbaik = 1.8505, f(x) = 2.8503
# Step 212: x terbaik = 1.8505, f(x) = 2.8503
# Step 213: x terbaik = 1.8505, f(x) = 2.8503
# Step 214: x terbaik = 1.8505, f(x) = 2.8503
# Step 215: x terbaik = 1.8505, f(x) = 2.8503
# Step 216: x terbaik = 1.8505, f(x) = 2.8503
# Step 217: x terbaik = 1.8505, f(x) = 2.8503
# Step 218: x terbaik = 1.8505, f(x) = 2.8503
# Step 219: x terbaik = 1.8505, f(x) = 2.8503
# Step 220: x terbaik = 1.8505, f(x) = 2.8503
# Step 221: x terbaik = 1.8505, f(x) = 2.8503
# Step 222: x terbaik = 1.8505, f(x) = 2.8503
# Step 223: x terbaik = 1.8505, f(x) = 2.8503
# Step 224: x terbaik = 1.8505, f(x) = 2.8503
# Step 225: x terbaik = 1.8505, f(x) = 2.8503
# Step 226: x terbaik = 1.8505, f(x) = 2.8503
# Step 227: x terbaik = 1.8505, f(x) = 2.8503
# Step 228: x terbaik = 1.8505, f(x) = 2.8503
# Step 229: x terbaik = 1.8505, f(x) = 2.8503
# Step 230: x terbaik = 1.8505, f(x) = 2.8503
# Step 231: x terbaik = 1.8505, f(x) = 2.8503
# Step 232: x terbaik = 1.8505, f(x) = 2.8503
# Step 233: x terbaik = 1.8505, f(x) = 2.8503
# Step 234: x terbaik = 1.8505, f(x) = 2.8503
# Step 235: x terbaik = 1.8505, f(x) = 2.8503
# Step 236: x terbaik = 1.8505, f(x) = 2.8503
# Step 237: x terbaik = 1.8505, f(x) = 2.8503
# Step 238: x terbaik = 1.8505, f(x) = 2.8503
# Step 239: x terbaik = 1.8505, f(x) = 2.8503
# Step 240: x terbaik = 1.8505, f(x) = 2.8503
# Step 241: x terbaik = 1.8505, f(x) = 2.8503
# Step 242: x terbaik = 1.8505, f(x) = 2.8503
# Step 243: x terbaik = 1.8505, f(x) = 2.8503
# Step 244: x terbaik = 1.8505, f(x) = 2.8503
# Step 245: x terbaik = 1.8505, f(x) = 2.8503
# Step 246: x terbaik = 1.8505, f(x) = 2.8503
# Step 247: x terbaik = 1.8505, f(x) = 2.8503
# Step 248: x terbaik = 1.8505, f(x) = 2.8503
# Step 249: x terbaik = 1.8505, f(x) = 2.8503
# Step 250: x terbaik = 1.8505, f(x) = 2.8503
# Step 251: x terbaik = 1.8505, f(x) = 2.8503
# Step 252: x terbaik = 1.8505, f(x) = 2.8503
# Step 253: x terbaik = 1.8505, f(x) = 2.8503
# Step 254: x terbaik = 1.8505, f(x) = 2.8503
# Step 255: x terbaik = 1.8505, f(x) = 2.8503
# Step 256: x terbaik = 1.8505, f(x) = 2.8503
# Step 257: x terbaik = 1.8505, f(x) = 2.8503
# Step 258: x terbaik = 1.8505, f(x) = 2.8503
# Step 259: x terbaik = 1.8505, f(x) = 2.8503
# Step 260: x terbaik = 1.8505, f(x) = 2.8503
# Step 261: x terbaik = 1.8505, f(x) = 2.8503
# Step 262: x terbaik = 1.8505, f(x) = 2.8503
# Step 263: x terbaik = 1.8505, f(x) = 2.8503
# Step 264: x terbaik = 1.8505, f(x) = 2.8503
# Step 265: x terbaik = 1.8505, f(x) = 2.8503
# Step 266: x terbaik = 1.8505, f(x) = 2.8503
# Step 267: x terbaik = 1.8505, f(x) = 2.8503
# Step 268: x terbaik = 1.8505, f(x) = 2.8503
# Step 269: x terbaik = 1.8505, f(x) = 2.8503
# Step 270: x terbaik = 1.8505, f(x) = 2.8503
# Step 271: x terbaik = 1.8505, f(x) = 2.8503
# Step 272: x terbaik = 1.8505, f(x) = 2.8503
# Step 273: x terbaik = 1.8505, f(x) = 2.8503
# Step 274: x terbaik = 1.8505, f(x) = 2.8503
# Step 275: x terbaik = 1.8505, f(x) = 2.8503
# Step 276: x terbaik = 1.8505, f(x) = 2.8503
# Step 277: x terbaik = 1.8505, f(x) = 2.8503
# Step 278: x terbaik = 1.8505, f(x) = 2.8503
# Step 279: x terbaik = 1.8505, f(x) = 2.8503
# Step 280: x terbaik = 1.8505, f(x) = 2.8503
# Step 281: x terbaik = 1.8505, f(x) = 2.8503
# Step 282: x terbaik = 1.8505, f(x) = 2.8503
# Step 283: x terbaik = 1.8505, f(x) = 2.8503
# Step 284: x terbaik = 1.8505, f(x) = 2.8503
# Step 285: x terbaik = 1.8505, f(x) = 2.8503
# Step 286: x terbaik = 1.8505, f(x) = 2.8503
# Step 287: x terbaik = 1.8505, f(x) = 2.8503
# Step 288: x terbaik = 1.8505, f(x) = 2.8503
# Step 289: x terbaik = 1.8505, f(x) = 2.8503
# Step 290: x terbaik = 1.8505, f(x) = 2.8503
# Step 291: x terbaik = 1.8505, f(x) = 2.8503
# Step 292: x terbaik = 1.8505, f(x) = 2.8503
# Step 293: x terbaik = 1.8505, f(x) = 2.8503
# Step 294: x terbaik = 1.8505, f(x) = 2.8503
# Step 295: x terbaik = 1.8505, f(x) = 2.8503
# Step 296: x terbaik = 1.8505, f(x) = 2.8503
# Step 297: x terbaik = 1.8505, f(x) = 2.8503
# Step 298: x terbaik = 1.8505, f(x) = 2.8503
# Step 299: x terbaik = 1.8505, f(x) = 2.8503
# Step 300: x terbaik = 1.8505, f(x) = 2.8503
# Step 301: x terbaik = 1.8505, f(x) = 2.8503
# Step 302: x terbaik = 1.8505, f(x) = 2.8503
# Step 303: x terbaik = 1.8505, f(x) = 2.8503
# Step 304: x terbaik = 1.8505, f(x) = 2.8503
# Step 305: x terbaik = 1.8505, f(x) = 2.8503
# Step 306: x terbaik = 1.8505, f(x) = 2.8503
# Step 307: x terbaik = 1.8505, f(x) = 2.8503
# Step 308: x terbaik = 1.8505, f(x) = 2.8503
# Step 309: x terbaik = 1.8505, f(x) = 2.8503
# Step 310: x terbaik = 1.8505, f(x) = 2.8503
# Step 311: x terbaik = 1.8505, f(x) = 2.8503
# Step 312: x terbaik = 1.8505, f(x) = 2.8503
# Step 313: x terbaik = 1.8505, f(x) = 2.8503
# Step 314: x terbaik = 1.8505, f(x) = 2.8503
# Step 315: x terbaik = 1.8505, f(x) = 2.8503
# Step 316: x terbaik = 1.8505, f(x) = 2.8503
# Step 317: x terbaik = 1.8505, f(x) = 2.8503
# Step 318: x terbaik = 1.8505, f(x) = 2.8503
# Step 319: x terbaik = 1.8505, f(x) = 2.8503
# Step 320: x terbaik = 1.8505, f(x) = 2.8503
# Step 321: x terbaik = 1.8505, f(x) = 2.8503
# Step 322: x terbaik = 1.8505, f(x) = 2.8503
# Step 323: x terbaik = 1.8505, f(x) = 2.8503
# Step 324: x terbaik = 1.8505, f(x) = 2.8503
# Step 325: x terbaik = 1.8505, f(x) = 2.8503
# Step 326: x terbaik = 1.8505, f(x) = 2.8503
# Step 327: x terbaik = 1.8505, f(x) = 2.8503
# Step 328: x terbaik = 1.8505, f(x) = 2.8503
# Step 329: x terbaik = 1.8505, f(x) = 2.8503
# Step 330: x terbaik = 1.8505, f(x) = 2.8503
# Step 331: x terbaik = 1.8505, f(x) = 2.8503
# Step 332: x terbaik = 1.8505, f(x) = 2.8503
# Step 333: x terbaik = 1.8505, f(x) = 2.8503
# Step 334: x terbaik = 1.8505, f(x) = 2.8503
# Step 335: x terbaik = 1.8505, f(x) = 2.8503
# Step 336: x terbaik = 1.8505, f(x) = 2.8503
# Step 337: x terbaik = 1.8505, f(x) = 2.8503
# Step 338: x terbaik = 1.8505, f(x) = 2.8503
# Step 339: x terbaik = 1.8505, f(x) = 2.8503
# Step 340: x terbaik = 1.8505, f(x) = 2.8503
# Step 341: x terbaik = 1.8505, f(x) = 2.8503
# Step 342: x terbaik = 1.8505, f(x) = 2.8503
# Step 343: x terbaik = 1.8505, f(x) = 2.8503
# Step 344: x terbaik = 1.8505, f(x) = 2.8503
# Step 345: x terbaik = 1.8505, f(x) = 2.8503
# Step 346: x terbaik = 1.8505, f(x) = 2.8503
# Step 347: x terbaik = 1.8505, f(x) = 2.8503
# Step 348: x terbaik = 1.8505, f(x) = 2.8503
# Step 349: x terbaik = 1.8505, f(x) = 2.8503
# Step 350: x terbaik = 1.8505, f(x) = 2.8503
# Step 351: x terbaik = 1.8505, f(x) = 2.8503
# Step 352: x terbaik = 1.8505, f(x) = 2.8503
# Step 353: x terbaik = 1.8505, f(x) = 2.8503
# Step 354: x terbaik = 1.8505, f(x) = 2.8503
# Step 355: x terbaik = 1.8505, f(x) = 2.8503
# Step 356: x terbaik = 1.8505, f(x) = 2.8503
# Step 357: x terbaik = 1.8505, f(x) = 2.8503
# Step 358: x terbaik = 1.8505, f(x) = 2.8503
# Step 359: x terbaik = 1.8505, f(x) = 2.8503
# Step 360: x terbaik = 1.8505, f(x) = 2.8503
# Step 361: x terbaik = 1.8505, f(x) = 2.8503
# Step 362: x terbaik = 1.8505, f(x) = 2.8503
# Step 363: x terbaik = 1.8505, f(x) = 2.8503
# Step 364: x terbaik = 1.8505, f(x) = 2.8503
# Step 365: x terbaik = 1.8505, f(x) = 2.8503
# Step 366: x terbaik = 1.8505, f(x) = 2.8503
# Step 367: x terbaik = 1.8505, f(x) = 2.8503
# Step 368: x terbaik = 1.8505, f(x) = 2.8503
# Step 369: x terbaik = 1.8505, f(x) = 2.8503
# Step 370: x terbaik = 1.8505, f(x) = 2.8503
# Step 371: x terbaik = 1.8505, f(x) = 2.8503
# Step 372: x terbaik = 1.8505, f(x) = 2.8503
# Step 373: x terbaik = 1.8505, f(x) = 2.8503
# Step 374: x terbaik = 1.8505, f(x) = 2.8503
# Step 375: x terbaik = 1.8505, f(x) = 2.8503
# Step 376: x terbaik = 1.8505, f(x) = 2.8503
# Step 377: x terbaik = 1.8505, f(x) = 2.8503
# Step 378: x terbaik = 1.8505, f(x) = 2.8503
# Step 379: x terbaik = 1.8505, f(x) = 2.8503
# Step 380: x terbaik = 1.8505, f(x) = 2.8503
# Step 381: x terbaik = 1.8505, f(x) = 2.8503
# Step 382: x terbaik = 1.8505, f(x) = 2.8503
# Step 383: x terbaik = 1.8505, f(x) = 2.8503
# Step 384: x terbaik = 1.8505, f(x) = 2.8503
# Step 385: x terbaik = 1.8505, f(x) = 2.8503
# Step 386: x terbaik = 1.8505, f(x) = 2.8503
# Step 387: x terbaik = 1.8505, f(x) = 2.8503
# Step 388: x terbaik = 1.8505, f(x) = 2.8503
# Step 389: x terbaik = 1.8505, f(x) = 2.8503
# Step 390: x terbaik = 1.8505, f(x) = 2.8503
# Step 391: x terbaik = 1.8505, f(x) = 2.8503
# Step 392: x terbaik = 1.8505, f(x) = 2.8503
# Step 393: x terbaik = 1.8505, f(x) = 2.8503
# Step 394: x terbaik = 1.8505, f(x) = 2.8503
# Step 395: x terbaik = 1.8505, f(x) = 2.8503
# Step 396: x terbaik = 1.8505, f(x) = 2.8503
# Step 397: x terbaik = 1.8505, f(x) = 2.8503
# Step 398: x terbaik = 1.8505, f(x) = 2.8503
# Step 399: x terbaik = 1.8505, f(x) = 2.8503
# Step 400: x terbaik = 1.8505, f(x) = 2.8503
# Step 401: x terbaik = 1.8505, f(x) = 2.8503
# Step 402: x terbaik = 1.8505, f(x) = 2.8503
# Step 403: x terbaik = 1.8505, f(x) = 2.8503
# Step 404: x terbaik = 1.8505, f(x) = 2.8503
# Step 405: x terbaik = 1.8505, f(x) = 2.8503
# Step 406: x terbaik = 1.8505, f(x) = 2.8503
# Step 407: x terbaik = 1.8505, f(x) = 2.8503
# Step 408: x terbaik = 1.8505, f(x) = 2.8503
# Step 409: x terbaik = 1.8505, f(x) = 2.8503
# Step 410: x terbaik = 1.8505, f(x) = 2.8503
# Step 411: x terbaik = 1.8505, f(x) = 2.8503
# Step 412: x terbaik = 1.8505, f(x) = 2.8503
# Step 413: x terbaik = 1.8505, f(x) = 2.8503
# Step 414: x terbaik = 1.8505, f(x) = 2.8503
# Step 415: x terbaik = 1.8505, f(x) = 2.8503
# Step 416: x terbaik = 1.8505, f(x) = 2.8503
# Step 417: x terbaik = 1.8505, f(x) = 2.8503
# Step 418: x terbaik = 1.8505, f(x) = 2.8503
# Step 419: x terbaik = 1.8505, f(x) = 2.8503
# Step 420: x terbaik = 1.8505, f(x) = 2.8503
# Step 421: x terbaik = 1.8505, f(x) = 2.8503
# Step 422: x terbaik = 1.8505, f(x) = 2.8503
# Step 423: x terbaik = 1.8505, f(x) = 2.8503
# Step 424: x terbaik = 1.8505, f(x) = 2.8503
# Step 425: x terbaik = 1.8505, f(x) = 2.8503
# Step 426: x terbaik = 1.8505, f(x) = 2.8503
# Step 427: x terbaik = 1.8505, f(x) = 2.8503
# Step 428: x terbaik = 1.8505, f(x) = 2.8503
# Step 429: x terbaik = 1.8505, f(x) = 2.8503
# Step 430: x terbaik = 1.8505, f(x) = 2.8503
# Step 431: x terbaik = 1.8505, f(x) = 2.8503
# Step 432: x terbaik = 1.8505, f(x) = 2.8503
# Step 433: x terbaik = 1.8505, f(x) = 2.8503
# Step 434: x terbaik = 1.8505, f(x) = 2.8503
# Step 435: x terbaik = 1.8505, f(x) = 2.8503
# Step 436: x terbaik = 1.8505, f(x) = 2.8503
# Step 437: x terbaik = 1.8505, f(x) = 2.8503
# Step 438: x terbaik = 1.8505, f(x) = 2.8503
# Step 439: x terbaik = 1.8505, f(x) = 2.8503
# Step 440: x terbaik = 1.8505, f(x) = 2.8503
# Step 441: x terbaik = 1.8505, f(x) = 2.8503
# Step 442: x terbaik = 1.8505, f(x) = 2.8503
# Step 443: x terbaik = 1.8505, f(x) = 2.8503
# Step 444: x terbaik = 1.8505, f(x) = 2.8503
# Step 445: x terbaik = 1.8505, f(x) = 2.8503
# Step 446: x terbaik = 1.8505, f(x) = 2.8503
# Step 447: x terbaik = 1.8505, f(x) = 2.8503
# Step 448: x terbaik = 1.8505, f(x) = 2.8503
# Step 449: x terbaik = 1.8505, f(x) = 2.8503
# Step 450: x terbaik = 1.8505, f(x) = 2.8503
# Step 451: x terbaik = 1.8505, f(x) = 2.8503
# Step 452: x terbaik = 1.8505, f(x) = 2.8503
# Step 453: x terbaik = 1.8505, f(x) = 2.8503
# Step 454: x terbaik = 1.8505, f(x) = 2.8503
# Step 455: x terbaik = 1.8505, f(x) = 2.8503
# Step 456: x terbaik = 1.8505, f(x) = 2.8503
# Step 457: x terbaik = 1.8505, f(x) = 2.8503
# Step 458: x terbaik = 1.8505, f(x) = 2.8503
# Step 459: x terbaik = 1.8505, f(x) = 2.8503
# Step 460: x terbaik = 1.8505, f(x) = 2.8503
# Step 461: x terbaik = 1.8505, f(x) = 2.8503
# Step 462: x terbaik = 1.8505, f(x) = 2.8503
# Step 463: x terbaik = 1.8505, f(x) = 2.8503
# Step 464: x terbaik = 1.8505, f(x) = 2.8503
# Step 465: x terbaik = 1.8505, f(x) = 2.8503
# Step 466: x terbaik = 1.8505, f(x) = 2.8503
# Step 467: x terbaik = 1.8505, f(x) = 2.8503
# Step 468: x terbaik = 1.8505, f(x) = 2.8503
# Step 469: x terbaik = 1.8505, f(x) = 2.8503
# Step 470: x terbaik = 1.8505, f(x) = 2.8503
# Step 471: x terbaik = 1.8505, f(x) = 2.8503
# Step 472: x terbaik = 1.8505, f(x) = 2.8503
# Step 473: x terbaik = 1.8505, f(x) = 2.8503
# Step 474: x terbaik = 1.8505, f(x) = 2.8503
# Step 475: x terbaik = 1.8505, f(x) = 2.8503
# Step 476: x terbaik = 1.8505, f(x) = 2.8503
# Step 477: x terbaik = 1.8505, f(x) = 2.8503
# Step 478: x terbaik = 1.8505, f(x) = 2.8503
# Step 479: x terbaik = 1.8505, f(x) = 2.8503
# Step 480: x terbaik = 1.8505, f(x) = 2.8503
# Step 481: x terbaik = 1.8505, f(x) = 2.8503
# Step 482: x terbaik = 1.8505, f(x) = 2.8503
# Step 483: x terbaik = 1.8505, f(x) = 2.8503
# Step 484: x terbaik = 1.8505, f(x) = 2.8503
# Step 485: x terbaik = 1.8505, f(x) = 2.8503
# Step 486: x terbaik = 1.8505, f(x) = 2.8503
# Step 487: x terbaik = 1.8505, f(x) = 2.8503
# Step 488: x terbaik = 1.8505, f(x) = 2.8503
# Step 489: x terbaik = 1.8505, f(x) = 2.8503
# Step 490: x terbaik = 1.8505, f(x) = 2.8503
# Step 491: x terbaik = 1.8505, f(x) = 2.8503
# Step 492: x terbaik = 1.8505, f(x) = 2.8503
# Step 493: x terbaik = 1.8505, f(x) = 2.8503
# Step 494: x terbaik = 1.8505, f(x) = 2.8503
# Step 495: x terbaik = 1.8505, f(x) = 2.8503
# Step 496: x terbaik = 1.8505, f(x) = 2.8503
# Step 497: x terbaik = 1.8505, f(x) = 2.8503
# Step 498: x terbaik = 1.8505, f(x) = 2.8503
# Step 499: x terbaik = 1.8505, f(x) = 2.8503
# Step 500: x terbaik = 1.8505, f(x) = 2.8503
# Step 501: x terbaik = 1.8505, f(x) = 2.8503
# Step 502: x terbaik = 1.8505, f(x) = 2.8503
# Step 503: x terbaik = 1.8505, f(x) = 2.8503
# Step 504: x terbaik = 1.8505, f(x) = 2.8503
# Step 505: x terbaik = 1.8505, f(x) = 2.8503
# Step 506: x terbaik = 1.8505, f(x) = 2.8503
# Step 507: x terbaik = 1.8505, f(x) = 2.8503
# Step 508: x terbaik = 1.8505, f(x) = 2.8503
# Step 509: x terbaik = 1.8505, f(x) = 2.8503
# Step 510: x terbaik = 1.8505, f(x) = 2.8503
# Step 511: x terbaik = 1.8505, f(x) = 2.8503
# Step 512: x terbaik = 1.8505, f(x) = 2.8503
# Step 513: x terbaik = 1.8505, f(x) = 2.8503
# Step 514: x terbaik = 1.8505, f(x) = 2.8503
# Step 515: x terbaik = 1.8505, f(x) = 2.8503
# Step 516: x terbaik = 1.8505, f(x) = 2.8503
# Step 517: x terbaik = 1.8505, f(x) = 2.8503
# Step 518: x terbaik = 1.8505, f(x) = 2.8503
# Step 519: x terbaik = 1.8505, f(x) = 2.8503
# Step 520: x terbaik = 1.8505, f(x) = 2.8503
# Step 521: x terbaik = 1.8505, f(x) = 2.8503
# Step 522: x terbaik = 1.8505, f(x) = 2.8503
# Step 523: x terbaik = 1.8505, f(x) = 2.8503
# Step 524: x terbaik = 1.8505, f(x) = 2.8503
# Step 525: x terbaik = 1.8505, f(x) = 2.8503
# Step 526: x terbaik = 1.8505, f(x) = 2.8503
# Step 527: x terbaik = 1.8505, f(x) = 2.8503
# Step 528: x terbaik = 1.8505, f(x) = 2.8503
# Step 529: x terbaik = 1.8505, f(x) = 2.8503
# Step 530: x terbaik = 1.8505, f(x) = 2.8503
# Step 531: x terbaik = 1.8505, f(x) = 2.8503
# Step 532: x terbaik = 1.8505, f(x) = 2.8503
# Step 533: x terbaik = 1.8505, f(x) = 2.8503
# Step 534: x terbaik = 1.8505, f(x) = 2.8503
# Step 535: x terbaik = 1.8505, f(x) = 2.8503
# Step 536: x terbaik = 1.8505, f(x) = 2.8503
# Step 537: x terbaik = 1.8505, f(x) = 2.8503
# Step 538: x terbaik = 1.8505, f(x) = 2.8503
# Step 539: x terbaik = 1.8505, f(x) = 2.8503
# Step 540: x terbaik = 1.8505, f(x) = 2.8503
# Step 541: x terbaik = 1.8505, f(x) = 2.8503
# Step 542: x terbaik = 1.8505, f(x) = 2.8503
# Step 543: x terbaik = 1.8505, f(x) = 2.8503
# Step 544: x terbaik = 1.8505, f(x) = 2.8503
# Step 545: x terbaik = 1.8505, f(x) = 2.8503
# Step 546: x terbaik = 1.8505, f(x) = 2.8503
# Step 547: x terbaik = 1.8505, f(x) = 2.8503
# Step 548: x terbaik = 1.8505, f(x) = 2.8503
# Step 549: x terbaik = 1.8505, f(x) = 2.8503
# Step 550: x terbaik = 1.8505, f(x) = 2.8503
# Step 551: x terbaik = 1.8505, f(x) = 2.8503
# Step 552: x terbaik = 1.8505, f(x) = 2.8503
# Step 553: x terbaik = 1.8505, f(x) = 2.8503
# Step 554: x terbaik = 1.8505, f(x) = 2.8503
# Step 555: x terbaik = 1.8505, f(x) = 2.8503
# Step 556: x terbaik = 1.8505, f(x) = 2.8503
# Step 557: x terbaik = 1.8505, f(x) = 2.8503
# Step 558: x terbaik = 1.8505, f(x) = 2.8503
# Step 559: x terbaik = 1.8505, f(x) = 2.8503
# Step 560: x terbaik = 1.8505, f(x) = 2.8503
# Step 561: x terbaik = 1.8505, f(x) = 2.8503
# Step 562: x terbaik = 1.8505, f(x) = 2.8503
# Step 563: x terbaik = 1.8505, f(x) = 2.8503
# Step 564: x terbaik = 1.8505, f(x) = 2.8503
# Step 565: x terbaik = 1.8505, f(x) = 2.8503
# Step 566: x terbaik = 1.8505, f(x) = 2.8503
# Step 567: x terbaik = 1.8505, f(x) = 2.8503
# Step 568: x terbaik = 1.8505, f(x) = 2.8503
# Step 569: x terbaik = 1.8505, f(x) = 2.8503
# Step 570: x terbaik = 1.8505, f(x) = 2.8503
# Step 571: x terbaik = 1.8505, f(x) = 2.8503
# Step 572: x terbaik = 1.8505, f(x) = 2.8503
# Step 573: x terbaik = 1.8505, f(x) = 2.8503
# Step 574: x terbaik = 1.8505, f(x) = 2.8503
# Step 575: x terbaik = 1.8505, f(x) = 2.8503
# Step 576: x terbaik = 1.8505, f(x) = 2.8503
# Step 577: x terbaik = 1.8505, f(x) = 2.8503
# Step 578: x terbaik = 1.8505, f(x) = 2.8503
# Step 579: x terbaik = 1.8505, f(x) = 2.8503
# Step 580: x terbaik = 1.8505, f(x) = 2.8503
# Step 581: x terbaik = 1.8505, f(x) = 2.8503
# Step 582: x terbaik = 1.8505, f(x) = 2.8503
# Step 583: x terbaik = 1.8505, f(x) = 2.8503
# Step 584: x terbaik = 1.8505, f(x) = 2.8503
# Step 585: x terbaik = 1.8505, f(x) = 2.8503
# Step 586: x terbaik = 1.8505, f(x) = 2.8503
# Step 587: x terbaik = 1.8505, f(x) = 2.8503
# Step 588: x terbaik = 1.8505, f(x) = 2.8503
# Step 589: x terbaik = 1.8505, f(x) = 2.8503
# Step 590: x terbaik = 1.8505, f(x) = 2.8503
# Step 591: x terbaik = 1.8505, f(x) = 2.8503
# Step 592: x terbaik = 1.8505, f(x) = 2.8503
# Step 593: x terbaik = 1.8505, f(x) = 2.8503
# Step 594: x terbaik = 1.8505, f(x) = 2.8503
# Step 595: x terbaik = 1.8505, f(x) = 2.8503
# Step 596: x terbaik = 1.8505, f(x) = 2.8503
# Step 597: x terbaik = 1.8505, f(x) = 2.8503
# Step 598: x terbaik = 1.8505, f(x) = 2.8503
# Step 599: x terbaik = 1.8505, f(x) = 2.8503
# Step 600: x terbaik = 1.8505, f(x) = 2.8503
# Step 601: x terbaik = 1.8505, f(x) = 2.8503
# Step 602: x terbaik = 1.8505, f(x) = 2.8503
# Step 603: x terbaik = 1.8505, f(x) = 2.8503
# Step 604: x terbaik = 1.8505, f(x) = 2.8503
# Step 605: x terbaik = 1.8505, f(x) = 2.8503
# Step 606: x terbaik = 1.8505, f(x) = 2.8503
# Step 607: x terbaik = 1.8505, f(x) = 2.8503
# Step 608: x terbaik = 1.8505, f(x) = 2.8503
# Step 609: x terbaik = 1.8505, f(x) = 2.8503
# Step 610: x terbaik = 1.8505, f(x) = 2.8503
# Step 611: x terbaik = 1.8505, f(x) = 2.8503
# Step 612: x terbaik = 1.8505, f(x) = 2.8503
# Step 613: x terbaik = 1.8505, f(x) = 2.8503
# Step 614: x terbaik = 1.8505, f(x) = 2.8503
# Step 615: x terbaik = 1.8505, f(x) = 2.8503
# Step 616: x terbaik = 1.8505, f(x) = 2.8503
# Step 617: x terbaik = 1.8505, f(x) = 2.8503
# Step 618: x terbaik = 1.8505, f(x) = 2.8503
# Step 619: x terbaik = 1.8505, f(x) = 2.8503
# Step 620: x terbaik = 1.8505, f(x) = 2.8503
# Step 621: x terbaik = 1.8505, f(x) = 2.8503
# Step 622: x terbaik = 1.8505, f(x) = 2.8503
# Step 623: x terbaik = 1.8505, f(x) = 2.8503
# Step 624: x terbaik = 1.8505, f(x) = 2.8503
# Step 625: x terbaik = 1.8505, f(x) = 2.8503
# Step 626: x terbaik = 1.8505, f(x) = 2.8503
# Step 627: x terbaik = 1.8505, f(x) = 2.8503
# Step 628: x terbaik = 1.8505, f(x) = 2.8503
# Step 629: x terbaik = 1.8505, f(x) = 2.8503
# Step 630: x terbaik = 1.8505, f(x) = 2.8503
# Step 631: x terbaik = 1.8505, f(x) = 2.8503
# Step 632: x terbaik = 1.8505, f(x) = 2.8503
# Step 633: x terbaik = 1.8505, f(x) = 2.8503
# Step 634: x terbaik = 1.8505, f(x) = 2.8503
# Step 635: x terbaik = 1.8505, f(x) = 2.8503
# Step 636: x terbaik = 1.8505, f(x) = 2.8503
# Step 637: x terbaik = 1.8505, f(x) = 2.8503
# Step 638: x terbaik = 1.8505, f(x) = 2.8503
# Step 639: x terbaik = 1.8505, f(x) = 2.8503
# Step 640: x terbaik = 1.8505, f(x) = 2.8503
# Step 641: x terbaik = 1.8505, f(x) = 2.8503
# Step 642: x terbaik = 1.8505, f(x) = 2.8503
# Step 643: x terbaik = 1.8505, f(x) = 2.8503
# Step 644: x terbaik = 1.8505, f(x) = 2.8503
# Step 645: x terbaik = 1.8505, f(x) = 2.8503
# Step 646: x terbaik = 1.8505, f(x) = 2.8503
# Step 647: x terbaik = 1.8505, f(x) = 2.8503
# Step 648: x terbaik = 1.8505, f(x) = 2.8503
# Step 649: x terbaik = 1.8505, f(x) = 2.8503
# Step 650: x terbaik = 1.8505, f(x) = 2.8503
# Step 651: x terbaik = 1.8505, f(x) = 2.8503
# Step 652: x terbaik = 1.8505, f(x) = 2.8503
# Step 653: x terbaik = 1.8505, f(x) = 2.8503
# Step 654: x terbaik = 1.8505, f(x) = 2.8503
# Step 655: x terbaik = 1.8505, f(x) = 2.8503
# Step 656: x terbaik = 1.8505, f(x) = 2.8503
# Step 657: x terbaik = 1.8505, f(x) = 2.8503
# Step 658: x terbaik = 1.8505, f(x) = 2.8503
# Step 659: x terbaik = 1.8505, f(x) = 2.8503
# Step 660: x terbaik = 1.8505, f(x) = 2.8503
# Step 661: x terbaik = 1.8505, f(x) = 2.8503
# Step 662: x terbaik = 1.8505, f(x) = 2.8503
# Step 663: x terbaik = 1.8505, f(x) = 2.8503
# Step 664: x terbaik = 1.8505, f(x) = 2.8503
# Step 665: x terbaik = 1.8505, f(x) = 2.8503
# Step 666: x terbaik = 1.8505, f(x) = 2.8503
# Step 667: x terbaik = 1.8505, f(x) = 2.8503
# Step 668: x terbaik = 1.8505, f(x) = 2.8503
# Step 669: x terbaik = 1.8505, f(x) = 2.8503
# Step 670: x terbaik = 1.8505, f(x) = 2.8503
# Step 671: x terbaik = 1.8505, f(x) = 2.8503
# Step 672: x terbaik = 1.8505, f(x) = 2.8503
# Step 673: x terbaik = 1.8505, f(x) = 2.8503
# Step 674: x terbaik = 1.8505, f(x) = 2.8503
# Step 675: x terbaik = 1.8505, f(x) = 2.8503
# Step 676: x terbaik = 1.8505, f(x) = 2.8503
# Step 677: x terbaik = 1.8505, f(x) = 2.8503
# Step 678: x terbaik = 1.8505, f(x) = 2.8503
# Step 679: x terbaik = 1.8505, f(x) = 2.8503
# Step 680: x terbaik = 1.8505, f(x) = 2.8503
# Step 681: x terbaik = 1.8505, f(x) = 2.8503
# Step 682: x terbaik = 1.8505, f(x) = 2.8503
# Step 683: x terbaik = 1.8505, f(x) = 2.8503
# Step 684: x terbaik = 1.8505, f(x) = 2.8503
# Step 685: x terbaik = 1.8505, f(x) = 2.8503
# Step 686: x terbaik = 1.8505, f(x) = 2.8503
# Step 687: x terbaik = 1.8505, f(x) = 2.8503
# Step 688: x terbaik = 1.8505, f(x) = 2.8503
# Step 689: x terbaik = 1.8505, f(x) = 2.8503
# Step 690: x terbaik = 1.8505, f(x) = 2.8503
# Step 691: x terbaik = 1.8505, f(x) = 2.8503
# Step 692: x terbaik = 1.8505, f(x) = 2.8503
# Step 693: x terbaik = 1.8505, f(x) = 2.8503
# Step 694: x terbaik = 1.8505, f(x) = 2.8503
# Step 695: x terbaik = 1.8505, f(x) = 2.8503
# Step 696: x terbaik = 1.8505, f(x) = 2.8503
# Step 697: x terbaik = 1.8505, f(x) = 2.8503
# Step 698: x terbaik = 1.8505, f(x) = 2.8503
# Step 699: x terbaik = 1.8505, f(x) = 2.8503
# Step 700: x terbaik = 1.8505, f(x) = 2.8503
# Step 701: x terbaik = 1.8505, f(x) = 2.8503
# Step 702: x terbaik = 1.8505, f(x) = 2.8503
# Step 703: x terbaik = 1.8505, f(x) = 2.8503
# Step 704: x terbaik = 1.8505, f(x) = 2.8503
# Step 705: x terbaik = 1.8505, f(x) = 2.8503
# Step 706: x terbaik = 1.8505, f(x) = 2.8503
# Step 707: x terbaik = 1.8505, f(x) = 2.8503
# Step 708: x terbaik = 1.8505, f(x) = 2.8503
# Step 709: x terbaik = 1.8505, f(x) = 2.8503
# Step 710: x terbaik = 1.8505, f(x) = 2.8503
# Step 711: x terbaik = 1.8505, f(x) = 2.8503
# Step 712: x terbaik = 1.8505, f(x) = 2.8503
# Step 713: x terbaik = 1.8505, f(x) = 2.8503
# Step 714: x terbaik = 1.8505, f(x) = 2.8503
# Step 715: x terbaik = 1.8505, f(x) = 2.8503
# Step 716: x terbaik = 1.8505, f(x) = 2.8503
# Step 717: x terbaik = 1.8505, f(x) = 2.8503
# Step 718: x terbaik = 1.8505, f(x) = 2.8503
# Step 719: x terbaik = 1.8505, f(x) = 2.8503
# Step 720: x terbaik = 1.8505, f(x) = 2.8503
# Step 721: x terbaik = 1.8505, f(x) = 2.8503
# Step 722: x terbaik = 1.8505, f(x) = 2.8503
# Step 723: x terbaik = 1.8505, f(x) = 2.8503
# Step 724: x terbaik = 1.8505, f(x) = 2.8503
# Step 725: x terbaik = 1.8505, f(x) = 2.8503
# Step 726: x terbaik = 1.8505, f(x) = 2.8503
# Step 727: x terbaik = 1.8505, f(x) = 2.8503
# Step 728: x terbaik = 1.8505, f(x) = 2.8503
# Step 729: x terbaik = 1.8505, f(x) = 2.8503
# Step 730: x terbaik = 1.8505, f(x) = 2.8503
# Step 731: x terbaik = 1.8505, f(x) = 2.8503
# Step 732: x terbaik = 1.8505, f(x) = 2.8503
# Step 733: x terbaik = 1.8505, f(x) = 2.8503
# Step 734: x terbaik = 1.8505, f(x) = 2.8503
# Step 735: x terbaik = 1.8505, f(x) = 2.8503
# Step 736: x terbaik = 1.8505, f(x) = 2.8503
# Step 737: x terbaik = 1.8505, f(x) = 2.8503
# Step 738: x terbaik = 1.8505, f(x) = 2.8503
# Step 739: x terbaik = 1.8505, f(x) = 2.8503
# Step 740: x terbaik = 1.8505, f(x) = 2.8503
# Step 741: x terbaik = 1.8505, f(x) = 2.8503
# Step 742: x terbaik = 1.8505, f(x) = 2.8503
# Step 743: x terbaik = 1.8505, f(x) = 2.8503
# Step 744: x terbaik = 1.8505, f(x) = 2.8503
# Step 745: x terbaik = 1.8505, f(x) = 2.8503
# Step 746: x terbaik = 1.8505, f(x) = 2.8503
# Step 747: x terbaik = 1.8505, f(x) = 2.8503
# Step 748: x terbaik = 1.8505, f(x) = 2.8503
# Step 749: x terbaik = 1.8505, f(x) = 2.8503
# Step 750: x terbaik = 1.8505, f(x) = 2.8503
# Step 751: x terbaik = 1.8505, f(x) = 2.8503
# Step 752: x terbaik = 1.8505, f(x) = 2.8503
# Step 753: x terbaik = 1.8505, f(x) = 2.8503
# Step 754: x terbaik = 1.8505, f(x) = 2.8503
# Step 755: x terbaik = 1.8505, f(x) = 2.8503
# Step 756: x terbaik = 1.8505, f(x) = 2.8503
# Step 757: x terbaik = 1.8505, f(x) = 2.8503
# Step 758: x terbaik = 1.8505, f(x) = 2.8503
# Step 759: x terbaik = 1.8505, f(x) = 2.8503
# Step 760: x terbaik = 1.8505, f(x) = 2.8503
# Step 761: x terbaik = 1.8505, f(x) = 2.8503
# Step 762: x terbaik = 1.8505, f(x) = 2.8503
# Step 763: x terbaik = 1.8505, f(x) = 2.8503
# Step 764: x terbaik = 1.8505, f(x) = 2.8503
# Step 765: x terbaik = 1.8505, f(x) = 2.8503
# Step 766: x terbaik = 1.8505, f(x) = 2.8503
# Step 767: x terbaik = 1.8505, f(x) = 2.8503
# Step 768: x terbaik = 1.8505, f(x) = 2.8503
# Step 769: x terbaik = 1.8505, f(x) = 2.8503
# Step 770: x terbaik = 1.8505, f(x) = 2.8503
# Step 771: x terbaik = 1.8505, f(x) = 2.8503
# Step 772: x terbaik = 1.8505, f(x) = 2.8503
# Step 773: x terbaik = 1.8505, f(x) = 2.8503
# Step 774: x terbaik = 1.8505, f(x) = 2.8503
# Step 775: x terbaik = 1.8505, f(x) = 2.8503
# Step 776: x terbaik = 1.8505, f(x) = 2.8503
# Step 777: x terbaik = 1.8505, f(x) = 2.8503
# Step 778: x terbaik = 1.8505, f(x) = 2.8503
# Step 779: x terbaik = 1.8505, f(x) = 2.8503
# Step 780: x terbaik = 1.8505, f(x) = 2.8503
# Step 781: x terbaik = 1.8505, f(x) = 2.8503
# Step 782: x terbaik = 1.8505, f(x) = 2.8503
# Step 783: x terbaik = 1.8505, f(x) = 2.8503
# Step 784: x terbaik = 1.8505, f(x) = 2.8503
# Step 785: x terbaik = 1.8505, f(x) = 2.8503
# Step 786: x terbaik = 1.8505, f(x) = 2.8503
# Step 787: x terbaik = 1.8505, f(x) = 2.8503
# Step 788: x terbaik = 1.8505, f(x) = 2.8503
# Step 789: x terbaik = 1.8505, f(x) = 2.8503
# Step 790: x terbaik = 1.8505, f(x) = 2.8503
# Step 791: x terbaik = 1.8505, f(x) = 2.8503
# Step 792: x terbaik = 1.8505, f(x) = 2.8503
# Step 793: x terbaik = 1.8505, f(x) = 2.8503
# Step 794: x terbaik = 1.8505, f(x) = 2.8503
# Step 795: x terbaik = 1.8505, f(x) = 2.8503
# Step 796: x terbaik = 1.8505, f(x) = 2.8503
# Step 797: x terbaik = 1.8505, f(x) = 2.8503
# Step 798: x terbaik = 1.8505, f(x) = 2.8503
# Step 799: x terbaik = 1.8505, f(x) = 2.8503
# Step 800: x terbaik = 1.8505, f(x) = 2.8503
# Step 801: x terbaik = 1.8505, f(x) = 2.8503
# Step 802: x terbaik = 1.8505, f(x) = 2.8503
# Step 803: x terbaik = 1.8505, f(x) = 2.8503
# Step 804: x terbaik = 1.8505, f(x) = 2.8503
# Step 805: x terbaik = 1.8505, f(x) = 2.8503
# Step 806: x terbaik = 1.8505, f(x) = 2.8503
# Step 807: x terbaik = 1.8505, f(x) = 2.8503
# Step 808: x terbaik = 1.8505, f(x) = 2.8503
# Step 809: x terbaik = 1.8505, f(x) = 2.8503
# Step 810: x terbaik = 1.8505, f(x) = 2.8503
# Step 811: x terbaik = 1.8505, f(x) = 2.8503
# Step 812: x terbaik = 1.8505, f(x) = 2.8503
# Step 813: x terbaik = 1.8505, f(x) = 2.8503
# Step 814: x terbaik = 1.8505, f(x) = 2.8503
# Step 815: x terbaik = 1.8505, f(x) = 2.8503
# Step 816: x terbaik = 1.8505, f(x) = 2.8503
# Step 817: x terbaik = 1.8505, f(x) = 2.8503
# Step 818: x terbaik = 1.8505, f(x) = 2.8503
# Step 819: x terbaik = 1.8505, f(x) = 2.8503
# Step 820: x terbaik = 1.8505, f(x) = 2.8503
# Step 821: x terbaik = 1.8505, f(x) = 2.8503
# Step 822: x terbaik = 1.8505, f(x) = 2.8503
# Step 823: x terbaik = 1.8505, f(x) = 2.8503
# Step 824: x terbaik = 1.8505, f(x) = 2.8503
# Step 825: x terbaik = 1.8505, f(x) = 2.8503
# Step 826: x terbaik = 1.8505, f(x) = 2.8503
# Step 827: x terbaik = 1.8505, f(x) = 2.8503
# Step 828: x terbaik = 1.8505, f(x) = 2.8503
# Step 829: x terbaik = 1.8505, f(x) = 2.8503
# Step 830: x terbaik = 1.8505, f(x) = 2.8503
# Step 831: x terbaik = 1.8505, f(x) = 2.8503
# Step 832: x terbaik = 1.8505, f(x) = 2.8503
# Step 833: x terbaik = 1.8505, f(x) = 2.8503
# Step 834: x terbaik = 1.8505, f(x) = 2.8503
# Step 835: x terbaik = 1.8505, f(x) = 2.8503
# Step 836: x terbaik = 1.8505, f(x) = 2.8503
# Step 837: x terbaik = 1.8505, f(x) = 2.8503
# Step 838: x terbaik = 1.8505, f(x) = 2.8503
# Step 839: x terbaik = 1.8505, f(x) = 2.8503
# Step 840: x terbaik = 1.8505, f(x) = 2.8503
# Step 841: x terbaik = 1.8505, f(x) = 2.8503
# Step 842: x terbaik = 1.8505, f(x) = 2.8503
# Step 843: x terbaik = 1.8505, f(x) = 2.8503
# Step 844: x terbaik = 1.8505, f(x) = 2.8503
# Step 845: x terbaik = 1.8505, f(x) = 2.8503
# Step 846: x terbaik = 1.8505, f(x) = 2.8503
# Step 847: x terbaik = 1.8505, f(x) = 2.8503
# Step 848: x terbaik = 1.8505, f(x) = 2.8503
# Step 849: x terbaik = 1.8505, f(x) = 2.8503
# Step 850: x terbaik = 1.8505, f(x) = 2.8503
# Step 851: x terbaik = 1.8505, f(x) = 2.8503
# Step 852: x terbaik = 1.8505, f(x) = 2.8503
# Step 853: x terbaik = 1.8505, f(x) = 2.8503
# Step 854: x terbaik = 1.8505, f(x) = 2.8503
# Step 855: x terbaik = 1.8505, f(x) = 2.8503
# Step 856: x terbaik = 1.8505, f(x) = 2.8503
# Step 857: x terbaik = 1.8505, f(x) = 2.8503
# Step 858: x terbaik = 1.8505, f(x) = 2.8503
# Step 859: x terbaik = 1.8505, f(x) = 2.8503
# Step 860: x terbaik = 1.8505, f(x) = 2.8503
# Step 861: x terbaik = 1.8505, f(x) = 2.8503
# Step 862: x terbaik = 1.8505, f(x) = 2.8503
# Step 863: x terbaik = 1.8505, f(x) = 2.8503
# Step 864: x terbaik = 1.8505, f(x) = 2.8503
# Step 865: x terbaik = 1.8505, f(x) = 2.8503
# Step 866: x terbaik = 1.8505, f(x) = 2.8503
# Step 867: x terbaik = 1.8505, f(x) = 2.8503
# Step 868: x terbaik = 1.8505, f(x) = 2.8503
# Step 869: x terbaik = 1.8505, f(x) = 2.8503
# Step 870: x terbaik = 1.8505, f(x) = 2.8503
# Step 871: x terbaik = 1.8505, f(x) = 2.8503
# Step 872: x terbaik = 1.8505, f(x) = 2.8503
# Step 873: x terbaik = 1.8505, f(x) = 2.8503
# Step 874: x terbaik = 1.8505, f(x) = 2.8503
# Step 875: x terbaik = 1.8505, f(x) = 2.8503
# Step 876: x terbaik = 1.8505, f(x) = 2.8503
# Step 877: x terbaik = 1.8505, f(x) = 2.8503
# Step 878: x terbaik = 1.8505, f(x) = 2.8503
# Step 879: x terbaik = 1.8505, f(x) = 2.8503
# Step 880: x terbaik = 1.8505, f(x) = 2.8503
# Step 881: x terbaik = 1.8505, f(x) = 2.8503
# Step 882: x terbaik = 1.8505, f(x) = 2.8503
# Step 883: x terbaik = 1.8505, f(x) = 2.8503
# Step 884: x terbaik = 1.8505, f(x) = 2.8503
# Step 885: x terbaik = 1.8505, f(x) = 2.8503
# Step 886: x terbaik = 1.8505, f(x) = 2.8503
# Step 887: x terbaik = 1.8505, f(x) = 2.8503
# Step 888: x terbaik = 1.8505, f(x) = 2.8503
# Step 889: x terbaik = 1.8505, f(x) = 2.8503
# Step 890: x terbaik = 1.8505, f(x) = 2.8503
# Step 891: x terbaik = 1.8505, f(x) = 2.8503
# Step 892: x terbaik = 1.8505, f(x) = 2.8503
# Step 893: x terbaik = 1.8505, f(x) = 2.8503
# Step 894: x terbaik = 1.8505, f(x) = 2.8503
# Step 895: x terbaik = 1.8505, f(x) = 2.8503
# Step 896: x terbaik = 1.8505, f(x) = 2.8503
# Step 897: x terbaik = 1.8505, f(x) = 2.8503
# Step 898: x terbaik = 1.8505, f(x) = 2.8503
# Step 899: x terbaik = 1.8505, f(x) = 2.8503
# Step 900: x terbaik = 1.8505, f(x) = 2.8503
# Step 901: x terbaik = 1.8505, f(x) = 2.8503
# Step 902: x terbaik = 1.8505, f(x) = 2.8503
# Step 903: x terbaik = 1.8505, f(x) = 2.8503
# Step 904: x terbaik = 1.8505, f(x) = 2.8503
# Step 905: x terbaik = 1.8505, f(x) = 2.8503
# Step 906: x terbaik = 1.8505, f(x) = 2.8503
# Step 907: x terbaik = 1.8505, f(x) = 2.8503
# Step 908: x terbaik = 1.8505, f(x) = 2.8503
# Step 909: x terbaik = 1.8505, f(x) = 2.8503
# Step 910: x terbaik = 1.8505, f(x) = 2.8503
# Step 911: x terbaik = 1.8505, f(x) = 2.8503
# Step 912: x terbaik = 1.8505, f(x) = 2.8503
# Step 913: x terbaik = 1.8505, f(x) = 2.8503
# Step 914: x terbaik = 1.8505, f(x) = 2.8503
# Step 915: x terbaik = 1.8505, f(x) = 2.8503
# Step 916: x terbaik = 1.8505, f(x) = 2.8503
# Step 917: x terbaik = 1.8505, f(x) = 2.8503
# Step 918: x terbaik = 1.8505, f(x) = 2.8503
# Step 919: x terbaik = 1.8505, f(x) = 2.8503
# Step 920: x terbaik = 1.8505, f(x) = 2.8503
# Step 921: x terbaik = 1.8505, f(x) = 2.8503
# Step 922: x terbaik = 1.8505, f(x) = 2.8503
# Step 923: x terbaik = 1.8505, f(x) = 2.8503
# Step 924: x terbaik = 1.8505, f(x) = 2.8503
# Step 925: x terbaik = 1.8505, f(x) = 2.8503
# Step 926: x terbaik = 1.8505, f(x) = 2.8503
# Step 927: x terbaik = 1.8505, f(x) = 2.8503
# Step 928: x terbaik = 1.8505, f(x) = 2.8503
# Step 929: x terbaik = 1.8505, f(x) = 2.8503
# Step 930: x terbaik = 1.8505, f(x) = 2.8503
# Step 931: x terbaik = 1.8505, f(x) = 2.8503
# Step 932: x terbaik = 1.8505, f(x) = 2.8503
# Step 933: x terbaik = 1.8505, f(x) = 2.8503
# Step 934: x terbaik = 1.8505, f(x) = 2.8503
# Step 935: x terbaik = 1.8505, f(x) = 2.8503
# Step 936: x terbaik = 1.8505, f(x) = 2.8503
# Step 937: x terbaik = 1.8505, f(x) = 2.8503
# Step 938: x terbaik = 1.8505, f(x) = 2.8503
# Step 939: x terbaik = 1.8505, f(x) = 2.8503
# Step 940: x terbaik = 1.8505, f(x) = 2.8503
# Step 941: x terbaik = 1.8505, f(x) = 2.8503
# Step 942: x terbaik = 1.8505, f(x) = 2.8503
# Step 943: x terbaik = 1.8505, f(x) = 2.8503
# Step 944: x terbaik = 1.8505, f(x) = 2.8503
# Step 945: x terbaik = 1.8505, f(x) = 2.8503
# Step 946: x terbaik = 1.8505, f(x) = 2.8503
# Step 947: x terbaik = 1.8505, f(x) = 2.8503
# Step 948: x terbaik = 1.8505, f(x) = 2.8503
# Step 949: x terbaik = 1.8505, f(x) = 2.8503
# Step 950: x terbaik = 1.8505, f(x) = 2.8503
# Step 951: x terbaik = 1.8505, f(x) = 2.8503
# Step 952: x terbaik = 1.8505, f(x) = 2.8503
# Step 953: x terbaik = 1.8505, f(x) = 2.8503
# Step 954: x terbaik = 1.8505, f(x) = 2.8503
# Step 955: x terbaik = 1.8505, f(x) = 2.8503
# Step 956: x terbaik = 1.8505, f(x) = 2.8503
# Step 957: x terbaik = 1.8505, f(x) = 2.8503
# Step 958: x terbaik = 1.8505, f(x) = 2.8503
# Step 959: x terbaik = 1.8505, f(x) = 2.8503
# Step 960: x terbaik = 1.8505, f(x) = 2.8503
# Step 961: x terbaik = 1.8505, f(x) = 2.8503
# Step 962: x terbaik = 1.8505, f(x) = 2.8503
# Step 963: x terbaik = 1.8505, f(x) = 2.8503
# Step 964: x terbaik = 1.8505, f(x) = 2.8503
# Step 965: x terbaik = 1.8505, f(x) = 2.8503
# Step 966: x terbaik = 1.8505, f(x) = 2.8503
# Step 967: x terbaik = 1.8505, f(x) = 2.8503
# Step 968: x terbaik = 1.8505, f(x) = 2.8503
# Step 969: x terbaik = 1.8505, f(x) = 2.8503
# Step 970: x terbaik = 1.8505, f(x) = 2.8503
# Step 971: x terbaik = 1.8505, f(x) = 2.8503
# Step 972: x terbaik = 1.8505, f(x) = 2.8503
# Step 973: x terbaik = 1.8505, f(x) = 2.8503
# Step 974: x terbaik = 1.8505, f(x) = 2.8503
# Step 975: x terbaik = 1.8505, f(x) = 2.8503
# Step 976: x terbaik = 1.8505, f(x) = 2.8503
# Step 977: x terbaik = 1.8505, f(x) = 2.8503
# Step 978: x terbaik = 1.8505, f(x) = 2.8503
# Step 979: x terbaik = 1.8505, f(x) = 2.8503
# Step 980: x terbaik = 1.8505, f(x) = 2.8503
# Step 981: x terbaik = 1.8505, f(x) = 2.8503
# Step 982: x terbaik = 1.8505, f(x) = 2.8503
# Step 983: x terbaik = 1.8505, f(x) = 2.8503
# Step 984: x terbaik = 1.8505, f(x) = 2.8503
# Step 985: x terbaik = 1.8505, f(x) = 2.8503
# Step 986: x terbaik = 1.8505, f(x) = 2.8503
# Step 987: x terbaik = 1.8505, f(x) = 2.8503
# Step 988: x terbaik = 1.8505, f(x) = 2.8503
# Step 989: x terbaik = 1.8505, f(x) = 2.8503
# Step 990: x terbaik = 1.8505, f(x) = 2.8503
# Step 991: x terbaik = 1.8505, f(x) = 2.8503
# Step 992: x terbaik = 1.8505, f(x) = 2.8503
# Step 993: x terbaik = 1.8505, f(x) = 2.8503
# Step 994: x terbaik = 1.8505, f(x) = 2.8503
# Step 995: x terbaik = 1.8505, f(x) = 2.8503
# Step 996: x terbaik = 1.8505, f(x) = 2.8503
# Step 997: x terbaik = 1.8505, f(x) = 2.8503
# Step 998: x terbaik = 1.8505, f(x) = 2.8503
# Step 999: x terbaik = 1.8505, f(x) = 2.8503
# Step 1000: x terbaik = 1.8505, f(x) = 2.8503
# Solusi terbaik: x = 1.8505, f(x) = 2.8503

# %% [markdown]
# **Step 5:** Visualisasi

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Konvergensi fitness
axes[0].plot(best_history, label='Best Fitness')
axes[0].plot(mean_history, label='Mean Fitness')
axes[0].set_xlabel('Generasi')
axes[0].set_ylabel('Fitness')
axes[0].set_title('Konvergensi GA')
axes[0].legend()
axes[0].grid(True)

# Plot 2: Populasi akhir pada fungsi objektif
x = np.linspace(X_MIN, X_MAX, 500)
axes[1].plot(x, fitness_function(x), 'b-', label='f(x)')
axes[1].scatter(population, fitness_function(population), c='red', zorder=5, label='Populasi Akhir')
axes[1].scatter(population[best_idx], final_fitness[best_idx], c='gold', s=200, marker='*', zorder=6, label='Terbaik')
axes[1].set_xlabel('x')
axes[1].set_ylabel('f(x)')
axes[1].set_title('Populasi Akhir pada Objective Function')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2><b>5. Perbandingan Ketiga Algoritma</b></h2>

# %% [markdown]
# <h3><b>5.1 Tabel Perbandingan</b></h3>
#
# | Aspek | Hill Climbing | Simulated Annealing | Genetic Algorithm |
# |---|---|---|---|
# | Tipe | Single-state | Single-state | Population-based |
# | Escape Local Optima | ✗ | ✓ (probabilistik) | ✓ (populasi + crossover) |
# | Parameter Tuning | Minimal | Moderate (T, α) | Kompleks (pop, mutation, crossover) |
# | Kecepatan | Cepat | Moderate | Lambat |
# | Memori | O(1) | O(1) | O(pop_size) |
# | Kualitas Solusi | Local optimum | Mendekati global | Mendekati global |

# %% [markdown]
# <h3><b>5.2 Kapan Menggunakan Local Search</b></h3>
#
# Gunakan Local Search ketika:
# - Kombinasi kemungkinan solusi terlalu masif
# - Hanya membutuhkan hasil akhir optimal
# - Kapasitas memori perangkat sangat terbatas
#
# Contoh aplikasi dunia nyata:
# - Sistem Navigasi: Mencari rute pengiriman paling optimal
# - Sistem Penjadwalan: Menyusun kelas tanpa jadwal bentrok

# %% [markdown]
# <h2><b>6. Hands-on</b></h2>

# %% [markdown]
# Tujuan
# - Mengimplementasikan Hill Climbing
# - Mengimplementasikan Simulated Annealing
# - Mengimplementasikan Genetic Algorithm
#
# Instruksi:
# - Lengkapi bagian kode yang kosong (_____)

# %% [markdown]
# <font color="blue">Latihan 1</font>

# %% [markdown]
# N-Queens Problem — Tempatkan N ratu pada papan N×N sehingga tidak ada yang saling menyerang.
# Gunakan Hill Climbing di mana: state = konfigurasi ratu (satu per kolom), neighbor = pindahkan 1 ratu dalam kolom,
# fitness = jumlah pasangan ratu yang TIDAK saling menyerang.

# %%
import random

def count_non_attacking(queens):
    """Hitung jumlah pasangan ratu yang tidak saling menyerang."""
    n = len(queens)
    non_attacking = 0
    for i in range(n):
        for j in range(i+1, n):
            if queens[i] != queens[j] and abs(queens[i] - queens[j]) != abs(i - j):
                # Cek bukan di diagonal yang sama
                non_attacking += 1
    return non_attacking

def get_neighbors_queens(queens):
    """Generate semua neighbor: pindahkan 1 ratu ke baris lain di kolomnya."""
    neighbors = []
    n = len(queens)
    for col in range(n):
        for row in range(n):
            if queens[col] != row:
                new_queens = list(queens)
                new_queens[col] = row
                neighbors.append(tuple(new_queens))
    return neighbors

def hill_climbing_queens(n=8, max_iter=1000):
    current = tuple(random.randint(0, n-1) for _ in range(n))
    current_fitness = count_non_attacking(current)
    max_fitness = n * (n - 1) // 2  # semua pasangan tidak menyerang

    for i in range(max_iter):
        if current_fitness == max_fitness:
            return current, current_fitness, True

        neighbors = get_neighbors_queens(current)
        best = max(neighbors, key=count_non_attacking)
        best_fitness = count_non_attacking(best)

        if best_fitness <= current_fitness:
            return current, current_fitness, False  # terjebak

        current = best
        current_fitness = best_fitness

    return current, current_fitness, False

# %%
sol, fit, success = hill_climbing_queens(8)
print(f"Solusi: {sol}, Fitness: {fit}, Berhasil: {success}")
# Out:
# Solusi: (4, 2, 7, 3, 6, 0, 1, 5), Fitness: 27, Berhasil: False

# %% [markdown]
# <font color="blue">Latihan 2</font>

# %% [markdown]
# Gunakan SA untuk memecahkan N-Queens Problem (N=8).
# Bandingkan success rate SA vs Hill Climbing dari 20 percobaan.

# %%
import random
import math

def sa_queens(n=8, T=4.0, alpha=0.99, n_iter=5000):
    current = list(range(n))
    random.shuffle(current)
    current_fitness = count_non_attacking(current)
    max_fitness = n * (n-1) // 2

    for i in range(n_iter):
        if current_fitness == max_fitness:
            return tuple(current), current_fitness, True

        new = current[:]
        col = random.randint(0, n-1)
        new[col] = random.randint(0, n-1)  # random row baru
        new_fitness = count_non_attacking(new)

        delta = new_fitness - current_fitness
        if delta > 0 or (T > 0 and random.random() < math.exp(delta / T)):
            current = new
            current_fitness = new_fitness

        T *= alpha

    return tuple(current), current_fitness, current_fitness == max_fitness

# %%
# Bandingkan SA vs HC
sa_success = sum(sa_queens()[2] for _ in range(20))
hc_success = sum(hill_climbing_queens()[2] for _ in range(20))
print(f"SA: {sa_success}/20, HC: {hc_success}/20")
# Out:
# SA: 19/20, HC: 1/20

# %% [markdown]
# <font color="blue">Latihan 3</font>

# %% [markdown]
# Implementasikan GA untuk TSP sederhana (6 kota).
# Gunakan permutation encoding, order crossover (OX1), dan swap mutation.

# %%
import random
import math

def total_distance(route, cities):
    """Menghitung total jarak tempuh rute TSP"""
    dist = 0
    for i in range(len(route)):
        city1 = route[i]
        city2 = route[(i + 1) % len(route)]
        dist += cities[city1][city2]
    return dist

cities = {
    'A': {'A': 0, 'B': 12, 'C': 10, 'D': 19, 'E': 8, 'F': 15},
    'B': {'A': 12, 'B': 0, 'C': 9, 'D': 14, 'E': 11, 'F': 17},
    'C': {'A': 10, 'B': 9, 'C': 0, 'D': 7, 'E': 13, 'F': 16},
    'D': {'A': 19, 'B': 14, 'C': 7, 'D': 0, 'E': 6, 'F': 20},
    'E': {'A': 8, 'B': 11, 'C': 13, 'D': 6, 'E': 0, 'F': 9},
    'F': {'A': 15, 'B': 17, 'C': 16, 'D': 20, 'E': 9, 'F': 0}
}

def order_crossover(p1, p2):
    n = len(p1)
    i, j = sorted(random.sample(range(n), 2))
    child = [None] * n
    child[i:j+1] = p1[i:j+1]  # segment dari p1
    fill = [g for g in p2 if g not in child[i:j+1]]
    idx = 0
    for k in range(n):
        if child[k] is None:
            child[k] = fill[idx]
            idx += 1
    return child

def swap_mutation(route, prob=0.1):
    if random.random() < prob:
        i, j = random.sample(range(len(route)), 2)
        route[i], route[j] = route[j], route[i]
    return route

def ga_tsp(cities, pop_size=50, gens=200):
    names = list(cities.keys())
    pop = [random.sample(names, len(names)) for _ in range(pop_size)]

    for gen in range(gens):
        fitnesses = [1 / total_distance(r, cities) for r in pop]
        new_pop = []
        for _ in range(pop_size // 2):
            p1 = max(random.sample(pop, 3), key=lambda r: 1/total_distance(r, cities))
            p2 = max(random.sample(pop, 3), key=lambda r: 1/total_distance(r, cities))
            c1 = order_crossover(p1, p2)
            c2 = order_crossover(p2, p1)
            new_pop.extend([swap_mutation(c1), swap_mutation(c2)])
        pop = new_pop

    best = min(pop, key=lambda r: total_distance(r, cities))
    return best, total_distance(best, cities)

# %%
route, dist = ga_tsp(cities)
print(f"GA TSP Route: {route}, Distance: {dist:.2f}")
# Out:
# GA TSP Route: ['C', 'D', 'E', 'F', 'A', 'B'], Distance: 58.00
